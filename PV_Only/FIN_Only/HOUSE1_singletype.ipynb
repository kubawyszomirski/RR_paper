# %%
# imports
import pandas as pd
import numpy as np
import numpy_financial as npf
import random  
import matplotlib.pyplot as plt
import time

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, DQN, A2C
from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback, EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from sb3_contrib import RecurrentPPO

from environment_fx_no_env import calculate_import_export, test1, test2, test3, evaluate1, evaluate2, basepolicy

import gymnasium as gym
from gymnasium import spaces

import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from typing import Callable

import torch
import torch as th
from torch import nn
import torch.nn as nn

# %%
# import and modify data

# Assuming the file is a CSV and specifying the correct path and filename
file_path = r"file_path"

# Use pandas to read the CSV file
AC_OUTPUT = pd.read_csv(file_path + "/AC_OUTPUT_JA")
elec_df = pd.read_csv(file_path + "/hourly_consumption2.csv")
import_price = pd.read_csv(file_path + "/electricity_tariff.csv")

#elec_df = elec_df * 1000
elec_df = elec_df.drop('HourOfYear', axis=1)

elec_df['hour_of_day'] = np.arange(8760) % 24
elec_df['day_of_week'] = np.arange(8760) // 24 % 7  # 0 is Monday, 6 is Sunday

# Define rates
peak_rate = 1.45
normal_rate = 1
off_peak_rate = 0.85

# Function to determine rate based on hour and day
def determine_rate(hour, day):
    if day < 5:  # Monday to Friday
        if 16 <= hour < 21:  # 4pm to 9pm
            return peak_rate
        elif 6 <= hour < 10:  # 7am to 9am and 10am to 3pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    else:  # Weekend
        if 16 <= hour < 21:  # 4pm to 9pm
            return normal_rate
        else:  # Off-peak times
            return off_peak_rate
    
# Apply the function to each row to determine the rate
elec_df['rate'] = elec_df.apply(lambda row: determine_rate(row['hour_of_day'], row['day_of_week']), axis=1)

import_price_df = import_price.drop(columns=['x'])
import_price_df = import_price_df[:-26]

train_cols = random.sample(list(import_price_df.columns), 7000)
import_price_train = import_price_df[train_cols]
test_cols = [col for col in import_price_df.columns if col not in train_cols]
import_price_test = import_price_df[test_cols]

Eff = pd.read_csv(file_path + "/Efficency_impr")
Eff = (Eff)/100 + 1

CAPEX = pd.read_csv(file_path + "/CAPEX_JA.csv")
CAPEX_JA = (CAPEX[:26]) * 1.3


train_cols_CAPEX = random.sample(list(CAPEX_JA.columns), 7000)
test_cols_CAPEX = [col for col in CAPEX_JA.columns if col not in train_cols_CAPEX]

CAPEX_JA_train = CAPEX_JA[train_cols_CAPEX]
CAPEX_JA_test = CAPEX_JA[test_cols_CAPEX]

train_cols_Eff = random.sample(list(Eff.columns), 7000)
test_cols_Eff = [col for col in Eff.columns if col not in train_cols_Eff]

Eff_train = Eff[train_cols_Eff]
Eff_test = Eff[test_cols_Eff]

AC_OUTPUT_arr = (np.array(AC_OUTPUT.T)).flatten()

Eff_train_arr = np.array(Eff_train.T)
Eff_test_arr = np.array(Eff_test.T)

CAPEX_JA_train_arr = np.array(CAPEX_JA_train.T)
CAPEX_JA_test_arr = np.array(CAPEX_JA_test.T)

elec_consum_arr = np.array(elec_df["Consumption"])
import_price_rate = np.array(elec_df["rate"])

import_price_train_arr = np.array(import_price_train.T)
import_price_test_arr = np.array(import_price_train.T)

# %%
class TrainEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 12
        
        # Degradation
        self.deg_mu = 0.82 # Trina: 1.19, JA: 0.82, Maxeon: 0.67
        self.deg_std = 0.555 
        
        self.phi = 30 # Trina: 15, JA: 30, Maxeon: 50

        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415  # Trina: 265, JA: 415, Maxeon: 435
        self.cost_per_Wp_df_at_zero = 0.69 # Trina: 0.36, JA: 0.69, Maxeon: 1.58
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        
        self.loan_interest_rate = 1.10
        self.normal_interest_rate = 1.02
        
        self.low_budget = 0 # Low budget: 0, High Budget: 750
        self.high_budget = 750 # Low budget: 750, High Budget: 1500
                        
        # Spaces and length
        self.action_space = spaces.Discrete(self.number_of_panels + 1)
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        """
        Calculate the annual Wh of energy exported to the grid (exported) and saved (minimised)
        """
        
        AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

        exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
        export_revenue = (export_price * exported).sum()

        
        minimised = AC_OUTPUT_tot - exported 
        minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum()
        

        return export_revenue, AC_OUTPUT_tot, minimised_revenue
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
        
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - self.import_price_df.min().min()) / (self.import_price_df.max().max() - self.import_price_df.min().min())
        self.FiT_at_zero_norm = (self.import_price_at_zero - self.import_price_df.min().min() * 0.33) / (self.import_price_df.max().max() - self.import_price_df.min().min() * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - self.cost_per_Wp_df.min().min()) / (self.cost_per_Wp_df.max().max() - self.cost_per_Wp_df.min().min())
        
        self.current_budget_constraint = np.random.randint(self.low_budget, self.high_budget)
        self.next_step_budget_constraint = 0
        
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0.]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        
        self.episode_len = 25  
    
        info = {}
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004

        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(self.low_budget, self.high_budget) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - self.low_budget * self.step_total_interest) / (self.high_budget * self.step_total_interest - self.low_budget * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
        
    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * self.phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
                        
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        current_penalty = 0
        self.other_costs = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        
        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(8)
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)

            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
                
        next_observation = self._get_obs()

        
        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices) #  ***
        
        self.pv_costs += resale
 
        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)

        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        pv_costs_observation = - self.pv_costs / 10000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 8000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        #reward = self.fin_balance_tot / 1000 if done else 0
        reward = self.fin_balance / 1000
        
        # FAILURE
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        survival = self.failure(actions_step)
        
        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1
                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.cost_per_Wp_df_at_zero - self.cost_per_Wp_df.min().min()) / (self.cost_per_Wp_df.max().max() - self.cost_per_Wp_df.min().min())
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
        
        info = {"step financial balance (eur):": self.fin_balance,
               "total financial balance: (eur)": self.fin_balance_tot,
               "internal rate of return": 0,
               "current_interest": resale,
                "net present value": 0}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
class TestEnvironment(gym.Env):
    def __init__(self, AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_tariff, efficency, CAPEX):
        
        # Price per watthour
        self.import_price_df = import_tariff
        self.import_price_at_zero = np.float32(0.00035)
        self.import_price_rate = import_price_rate
        
        # Energy Balance
        self.AC_OUTPUT = AC_OUTPUT_arr
        self.elec_df = elec_consum_arr
        self.max_export = 4000
        self.number_of_panels = 12
        
        # Degradation
        self.deg_mu = 0.82 # Trina: 1.19, JA: 0.82, Maxeon: 0.67
        self.deg_std = 0.555 
        
        self.phi = 30 # Trina: 15, JA: 30, Maxeon: 50

        
        # Efficency Development
        self.efficency_develop_df = efficency
        self.efficency_at_zero = 1.0
        
        # Costs
        self.power_at_zero = 415  # Trina: 265, JA: 415, Maxeon: 435
        self.cost_per_Wp_df_at_zero = 0.69 # Trina: 0.36, JA: 0.69, Maxeon: 1.58
        self.cost_per_Wp_df = CAPEX
        self.initial_other_costs = 150
        
        self.operational_cost = 16.8
        
        self.loan_interest_rate = 1.10
        self.normal_interest_rate = 1.02
        
        self.low_budget = 0 # Low budget: 0, High Budget: 750
        self.high_budget = 750 # Low budget: 750, High Budget: 1500
                        
        # Spaces and length
        self.action_space = spaces.Discrete(self.number_of_panels + 1)
        self.observation_space = spaces.Box(0, 1.25, shape=(self.number_of_panels + 7,))
        self.episode_len = 25
        self.months_per_timestep = 12
        
    def _get_obs(self):
        
        return self.observation
    
    def calculate_import_export(self, AC_OUTPUT, elec_df, export_price, import_price):
        
        """
        Calculate the annual Wh of energy exported to the grid (exported) and saved (minimised)
        """
        
        AC_OUTPUT_tot = self._get_obs()[0:self.number_of_panels].sum() * self.AC_OUTPUT 

        exported = (AC_OUTPUT_tot - self.elec_df).clip(min=0, max = self.max_export)        
        export_revenue = (export_price * exported).sum()

        
        minimised = AC_OUTPUT_tot - exported 
        minimised_revenue = (minimised * (self.import_price_rate * import_price)).sum()
        

        return export_revenue, AC_OUTPUT_tot, minimised_revenue
    
    def reset(self, seed=None):
        
        """
        Reset the environment to the original state at t=1
        """
        if seed is not None:
            random.seed(seed)
            np.random.seed(seed)
            
        # Panels
        self.init_obs = np.random.uniform(0, 1, size=self.number_of_panels).astype(np.float32)
        self.init_obs = np.where(self.init_obs < 0.5, 0.0, np.random.uniform(0.85, 1.0, size=self.number_of_panels))

        # Combine all initialization into a single step for efficiency
        self.import_price_at_zero_norm = (self.import_price_at_zero - self.import_price_df.min().min()) / (self.import_price_df.max().max() - self.import_price_df.min().min())
        self.FiT_at_zero_norm = (self.import_price_at_zero - self.import_price_df.min().min() * 0.33) / (self.import_price_df.max().max() - self.import_price_df.min().min() * 0.33)
        self.efficency_at_zero_norm = (self.efficency_at_zero - 0.999) / (1.156 - 0.999)
        self.panel_cost_and_inverter_at_zero_norm = (self.cost_per_Wp_df_at_zero - self.cost_per_Wp_df.min().min()) / (self.cost_per_Wp_df.max().max() - self.cost_per_Wp_df.min().min())

        
        self.current_budget_constraint = np.random.randint(self.low_budget, self.high_budget)
        self.next_step_budget_constraint = 0
        
        
        # Complete observation initialization in one go
        self.observation = np.concatenate([
            self.init_obs,
            [self.import_price_at_zero_norm, self.FiT_at_zero_norm, self.efficency_at_zero_norm, 
             self.panel_cost_and_inverter_at_zero_norm, 0., 0., 0.]
        ]).astype(np.float32)

        self.previous_observation = self.observation.copy()

        # RANDOM IMPORT PRICE
        self.random_import_price = self.import_price_df[np.random.choice(self.import_price_df.shape[0])] 

        # RANDOM EFFICENCY
        self.random_efficency_develop = self.efficency_develop_df[np.random.choice(self.efficency_develop_df.shape[0])]   
        
        # RANDOM COST PER WP
        self.random_cost_per_Wp = self.cost_per_Wp_df[np.random.choice(self.cost_per_Wp_df.shape[0])]   
        
        
        self.episode_len = 25  
    
        info = {}
        
        # RESET BALANCES
        self.fin_balance_tot = 0
        self.reward_tot = 0
        self.env_balance_tot = 0
        self.produced = 0
        self.other_costs = 0
        self.FiT = 0.0004
        self.next_FiT = 0.0004
        self.resale_values = array_of_zeros = np.zeros(self.number_of_panels, dtype=np.float32)
        
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)
        self.total_cash_flow = []
        self.annual_cash_flow = 0
                
        self.due_loans = [0, 0, 0, 0] 
        self.current_interest = 0
        self.step_total_interest = 1
        
        self.two_year_ago_interest = 0
        self.first_year_interest = []
        self.second_year_interest = [0]
        self.third_year_interest = [0, 0]
        self.fourth_year_interest = [0, 0, 0]
        self.next_year_total = 0
        
        self.survival = np.zeros(self.number_of_panels, dtype=np.float32)
    
        return self.observation, info
    
    def calculate_resale(self, initial_panel_cost, indices):
        
        self.resale_values[indices] = initial_panel_cost
        
        self.resale_values = self.resale_values * 0.85
        
        for count, i in enumerate(self.broke):
            if i == 1:
                self.resale_values[count] = 0
        
        resale_step = self.resale_values[indices].sum()
        
        return resale_step
    
    def calculate_panel_inv_cost(self, cost_per_Wp):
        
        PW_ep = self.efficency_develop * self.power_at_zero
        
        panel_cost_and_inverter = PW_ep * cost_per_Wp
        
        return panel_cost_and_inverter
    
    def calculate_irr_and_npv(self, pv_cost, minimised_revenue, export_revenue, penalty):
                
        """
        Calculates total cash flow of the project needed for the internal rate of return
        """ 
        self.expences = 0
        self.annual_cash_flow = 0
        initial_cost = 0
        
        self.expences = pv_cost
        self.annual_cash_flow = self.expences + export_revenue + minimised_revenue + penalty
        initial_cost_q, x = self.calculate_total_CAPEX(self.init_obs, self.panel_cost_and_inverter)
        initial_cost = - initial_cost_q
        
        if self.episode_len == 24:
            self.total_cash_flow.append(initial_cost + self.annual_cash_flow) 
        else:
            self.total_cash_flow.append(self.annual_cash_flow) 
        
        return self.total_cash_flow
        
    def calculate_penalty(self, current_step, annual_expense):
              
        year = 25 - current_step
        
        if year > 0:
            self.current_budget_constraint = self.next_step_budget_constraint    
            
        
        self.current_interest = self.next_year_total
        annual_expense = (-annual_expense)
        value = 0 
        loan = 0
        annual_interest = 0

        if annual_expense > self.current_budget_constraint:
            loan = (self.current_budget_constraint - annual_expense)
            value = annual_expense / self.current_budget_constraint
            periods = 2 if value < 2 else 3 if value < 3 else 4

            annual_interest = loan / periods
            interest_multiplier = 1

            for i in range(4):
                if i < periods:
                    self.due_loans[i] = annual_interest * interest_multiplier
                    interest_multiplier *= self.loan_interest_rate
                else:
                    self.due_loans[i] = 0
        else:
             self.due_loans = [0, 0, 0, 0]
    
        self.first_year_interest.append(self.due_loans[0])
        self.second_year_interest.append(self.due_loans[1])
        self.third_year_interest.append(self.due_loans[2])
        self.fourth_year_interest.append(self.due_loans[3])
    
    
        self.next_year_total = self.first_year_interest[year] + self.second_year_interest[year] + self.third_year_interest[year] + self.fourth_year_interest[year]
        
        self.next_step_budget_constraint = np.random.randint(self.low_budget, self.high_budget) * self.step_total_interest
        current_budget_observation = (self.next_step_budget_constraint - self.low_budget * self.step_total_interest) / (self.high_budget * self.step_total_interest - self.low_budget * self.step_total_interest) 
        self.observation[self.number_of_panels + 6] = current_budget_observation
                
        return self.current_interest, self.due_loans, self.next_year_total
        
    def calculate_total_CAPEX(self, action_step, panel_cost_and_inverter):
        """
        Calculate CAPEX each step in a vectorized manner.
        """
        BOS = panel_cost_and_inverter * 0.55
        number_installed = int(np.sum(action_step))

        # Calculate costs from module and inverter
        panel_cost_and_inverter_step = panel_cost_and_inverter * number_installed

        # Calculate other installation costs
        if number_installed == 0:
            other_costs = 0
        elif number_installed == 1:
            other_costs = self.initial_other_costs * self.step_total_interest
        else:
            discounts = 0.9 ** np.arange(number_installed)
            other_costs = (self.initial_other_costs * self.step_total_interest * discounts).sum()

        # Calculate BOS costs using vector operations
        is_new_installation = (self.previous_observation[:number_installed] == 0) & (action_step[:number_installed] == 1)
        is_replacement = (self.previous_observation[:number_installed] > 0) & (action_step[:number_installed] == 1)
        BOS_cost = np.sum(BOS * is_new_installation) + np.sum((BOS / 2) * is_replacement)

        # Sum total CAPEX
        total_CAPEX = panel_cost_and_inverter_step + BOS_cost + other_costs

        return total_CAPEX, panel_cost_and_inverter
        
    def failure(self, actions):
        
        beta = 3  # Shape parameter

        # Determine which panels are active based on the actions and previous observations.
        if self.episode_len == 24:
            active_panels = (self.observation[:self.number_of_panels] > 0.85)
        else:
            active_panels = (self.observation[:self.number_of_panels] == self.efficency_develop)

        # Calculate lifespan for all active panels at once
        lifespans = np.random.weibull(beta, self.number_of_panels) * self.phi
        lifespans = np.where(active_panels, lifespans, 0)  # Apply lifespan only to active panels

        # Adjust survival times based on episode length
        self.survival[:self.number_of_panels] = np.where(
            active_panels,
            np.abs(lifespans.astype(int)) + np.abs(self.episode_len - 25),
            self.survival[:self.number_of_panels]
        )

        return self.survival

    def calculate_FiT(self, episodes, import_price):
            
        self.FiT = import_price
            
        if episodes == 25:
            self.FiT = self.FiT
            
        elif episodes == 24 or episodes == 23:
            self.FiT = self.FiT * 0.64
            
        elif episodes == 22:
            self.FiT = self.FiT * 0.46
            
        elif episodes == 21:
            self.FiT = self.FiT * 0.55
            
        elif episodes < 20:
            self.FiT = self.FiT * 0.33
            
        elif episodes == 20:
            self.FiT = self.FiT * 0.37
            
        return self.FiT
                        
    def step(self, action):
        
        """
        defines actions, reward etc.
        """
        
        # RESET THE ANNUAL BALANCES
        self.total_CAPEX = 0
        self.pv_costs = 0
        self.fin_balance = 0
        self.number_installed = 0
        irr_fin = 0
        npv_fin = 0
        current_penalty = 0
        self.other_costs = 0
        next_step_penalty = 0
        self.step_total_interest = self.step_total_interest * self.normal_interest_rate
        current_operational_costs = self.operational_cost * self.step_total_interest
        
        
        self.cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
        self.import_price = self.random_import_price[abs(self.episode_len - 25)]
        self.efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
           
        self.panel_cost_and_inverter = self.calculate_panel_inv_cost(self.cost_per_Wp)
        FiT = self.calculate_FiT(self.episode_len, self.import_price)
        
        reward = 0   
        actions_step = np.random.rand(self.number_of_panels + 1)
        
        
        # Find indices of the lowest 'action' values in previous_observation
        indices = np.argsort(self.previous_observation[:self.number_of_panels])[:action]

        # Replace these indices in the observation with efficiency_develop
        self.observation[:self.number_of_panels][indices] = self.efficency_develop

        # Copy over the other values from previous_observation to observation
        mask = np.ones(len(self.previous_observation[:self.number_of_panels]), dtype=bool)
        mask[indices] = False
        self.observation[:self.number_of_panels][mask] = self.previous_observation[:self.number_of_panels][mask]

        replaced_panels = np.zeros(len(self.previous_observation[:self.number_of_panels]), dtype=int)
        replaced_panels[indices] = 1

        instaltion = (self.observation[:self.number_of_panels] > 0).astype(int)
        self.pv_costs -= instaltion.sum() * current_operational_costs

        actions_step = np.array(replaced_panels)

            
        if action > 0:
            step_CAPEX, panel_cost_and_inverter = self.calculate_total_CAPEX(actions_step, self.panel_cost_and_inverter)
            self.pv_costs -= step_CAPEX
            
        else:
            panel_cost_and_inverter = 0
                
        next_observation = self._get_obs()

        # Calculate the Reslae value
        resale = self.calculate_resale(panel_cost_and_inverter, indices) #  ***
        
        self.pv_costs += resale

        
        # CALCULATE THE BUDGET INTEREST
        current_penalty, due_loans, next_step_penalty = self.calculate_penalty(self.episode_len, self.pv_costs)
        
        
        # CALCULATE THE ENERGY YIELD
        exported_revenue, AC_OUTPUT_tot, minimised_revenue = self.calculate_import_export(self.AC_OUTPUT, 
                                                                          self.elec_df, FiT, self.import_price)        
        
        pv_costs_observation = - self.pv_costs / 10000
        self.observation[self.number_of_panels + 4] = pv_costs_observation
        
        next_step_penalty_observation = - next_step_penalty / 8000
        self.observation[self.number_of_panels + 5] = next_step_penalty_observation
        
        
        # CALCULATE STEP BALANCES
        self.fin_balance += self.pv_costs
        self.fin_balance += current_penalty
        self.fin_balance += float(exported_revenue + minimised_revenue)
        
        # CALCULATE TOTAL BALANCES
        self.fin_balance_tot += self.fin_balance                
        
        # SUBSTRACT 1 FOR TIMESTEP
        self.episode_len -= 1
        done = self.episode_len <= 0
        
        # CALCULATE IRR, NPV AND CARBON INTENSITY
        total_cash_flow = self.calculate_irr_and_npv(self.pv_costs, exported_revenue, minimised_revenue, current_penalty)
        irr = npf.irr(total_cash_flow) * 100
        npv = npf.npv(0.04 ,total_cash_flow)
            
        # RETURNS AND CALCULATE REWARD
        if self.episode_len == 0:
            irr_fin = irr
            npv_fin = npv
        
        reward = self.fin_balance / 1000
        
        # FAILURE
         
        survival = self.failure(actions_step)
        self.broke = np.zeros(self.number_of_panels, dtype=np.float32)

        for c, p in enumerate(survival):
            
            if c < self.number_of_panels:

                if p - 1 <= abs(self.episode_len - 24):
                    self.broke[c] = 1

                    self.observation[c] = 0
        
        # DEGRADATION RATE
        # Applying degradation only to panels that are operational (above 0.1 efficiency)
        active_panels = self.observation[:self.number_of_panels] > 0.1
        degradations = np.random.normal(self.deg_mu, self.deg_std, size=self.number_of_panels) / 100
        self.observation[:self.number_of_panels][active_panels] -= degradations[active_panels]
        
        if not done: 
        
            self.next_cost_per_Wp = self.random_cost_per_Wp[abs(self.episode_len - 25)]
            self.next_import_price = self.random_import_price[abs(self.episode_len - 25)]
            self.next_efficency_develop = self.random_efficency_develop[abs(self.episode_len - 25)]
            next_FIT = self.calculate_FiT(self.episode_len, self.next_import_price)
        
            price_observation = (self.next_import_price - 0.00022499) / (0.0020798 - 0.00022499)
            self.observation[self.number_of_panels] = price_observation

            FiT_observation = (next_FIT - 0.00022499 * 0.33) / (0.0020798 - 0.00022499 * 0.33)
            self.observation[self.number_of_panels + 1] = FiT_observation

            eff_observation = (self.next_efficency_develop - 0.999) / (1.156 - 0.999)
            self.observation[self.number_of_panels + 2] = eff_observation

            cost_per_Wp_observation = (self.cost_per_Wp_df_at_zero - self.cost_per_Wp_df.min().min()) / (self.cost_per_Wp_df.max().max() - self.cost_per_Wp_df.min().min())
            self.observation[self.number_of_panels + 3] = cost_per_Wp_observation
        
        
        info = {"step financial balance (eur):": self.fin_balance,
               "total financial balance: (eur)": self.fin_balance_tot,
               "internal rate of return": irr_fin,
               "current_interest": current_penalty,
                "net present value": npv_fin}
         
        
        self.previous_observation = self.observation.copy()
        
        return self.observation, reward, done, False, info

# %%
env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr)
env_test = TestEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_test_arr, Eff_test_arr, CAPEX_JA_test_arr)

# %%
check_env(env)

# %%
test3(1, env)
# Out:
# (array([0.        , 0.8728532 , 0.9126229 , 0.8696934 , 0.9406177 ,
#        0.90742123, 0.9843079 , 0.9951692 , 0.93203276, 0.89122355,
#        0.        , 0.        , 0.06935652, 0.11512984, 0.00636943,
#        0.55399454, 0.        , 0.        , 0.        ], dtype=float32), {})
#
# STEP: 1
# ACT
#  7
# OBS
#  [0.99512255 0.99799323 0.90016794 0.98982257 0.9422331  0.9898271
#  0.9715873  0.9866422  0.9248598  0.99628246 0.9998283  0.98735833
#  0.04258632 0.05998355 0.00636947 0.55399454 0.19065562 0.05054863
#  0.22933333]
# step financial balance (eur): -102.77738519565537 current_interest 2214.9172
#
#
# STEP: 2
# ACT
#  11
# OBS
#  [0.99277085 0.9841646  0.99094707 0.98467374 0.9970173  1.0011727
#  0.9796923  0.98735785 0.9875257  1.00404    0.9896332  0.99598545
#  0.05745011 0.06878136 0.02931093 0.55399454 0.28712252 0.13984679
#  0.74666667]
# step financial balance (eur): -2253.329629529107 current_interest 3380.0535
#
#
# STEP: 3
# ACT
#  8
# OBS
#  [0.99407727 0.9931505  0.9937387  0.9915658  0.9993947  0.99140733
#  1.0080982  0.9984625  0.9886995  1.0022324  0.9945405  0.9912931
#  0.04782161 0.03492837 0.02931093 0.55399454 0.20969258 0.20115338
#  0.98933333]
# step financial balance (eur): -2098.1720236957476 current_interest 2329.6492
#
#
# STEP: 4
# ACT
#  8
# OBS
#  [0.9975645  0.9965804  0.9976906  0.9988703  0.99220574 0.9942315
#  1.0101782  0.99418455 0.9916572  0.9933169  0.99040836 0.9941756
#  0.06301887 0.05673557 0.05845634 0.55399454 0.20258293 0.27286926
#  0.736     ]
# step financial balance (eur): -2874.7742619313753 current_interest 2331.5159
#
#
# STEP: 5
# ACT
#  9
# OBS
#  [1.0090388  1.0086788  0.9960349  0.9834474  0.99500895 0.9923466
#  1.009372   1.0109035  1.003641   0.99900186 0.9972099  0.99416137
#  0.0781469  0.03122841 0.05845634 0.55399454 0.22768058 0.27862617
#  0.05066667]
# step financial balance (eur): -3465.243574739266 current_interest 2651.2793
#
#
# STEP: 6
# ACT
#  3
# OBS
#  [0.995398   1.00274    0.9836332  0.99482054 0.9947532  0.9944753
#  1.0108633  1.0011008  0.9951909  0.9972668  0.99231607 1.0070034
#  0.08529674 0.02603224 0.09114591 0.55399454 0.08339623 0.20789842
#  0.5506667 ]
# step financial balance (eur): -2341.054498847205 current_interest 845.1436
#
#
# STEP: 7
# ACT
#  1
# OBS
#  [0.99540555 1.0020503  1.0052706  0.9961523  0.9929518  0.9810526
#  1.0083716  0.9925371  0.9847128  0.9955544  0.994741   0.998397
#  0.08351929 0.02548977 0.16090956 0.55399454 0.04526001 0.0907239
#  0.58533335]
# step financial balance (eur): -1451.9729185076735 current_interest 276.09293
#
#
# STEP: 8
# ACT
#  3
# OBS
#  [0.97872907 0.9926436  0.99231464 0.98265606 0.992506   1.0164963
#  0.99921215 1.0240276  1.0137854  0.98765254 0.9892132  0.99146116
#  0.10177621 0.03106171 0.22528093 0.55399454 0.08612227 0.12210565
#  0.104     ]
# step financial balance (eur): -925.4879918747286 current_interest 842.84125
#
#
# STEP: 9
# ACT
#  7
# OBS
#  [1.0228107  0.97947323 1.0269012  1.0239227  1.0249268  1.0064669
#  0.9838749  1.0241914  1.001831   1.0282893  1.0274137  1.0278466
#  0.09411301 0.02872294 0.22528093 0.55399454 0.1897209  0.11391471
#  0.81733334]
# step financial balance (eur): -2140.126663987655 current_interest 1995.4724
#
#
# STEP: 10
# ACT
#  5
# OBS
#  [1.0259805  1.030791   1.0115488  1.0166764  1.0137362  1.0151881
#  1.0212351  1.0148861  1.0360684  1.0105829  1.0245599  1.0120481
#  0.09694613 0.02958759 0.22528163 0.55399454 0.14037266 0.10402098
#  0.6346667 ]
# step financial balance (eur): -1602.3752183489637 current_interest 1337.7427
#
#
# STEP: 11
# ACT
#  4
# OBS
#  [1.0139683  1.0134768  1.0291872  1.005319   1.0298136  1.0023638
#  1.0258951  1.0045214  1.0235099  1.0322602  1.0151817  1.0257392
#  0.10060856 0.03070536 0.22538169 0.55399454 0.11546315 0.15032247
#  0.44933334]
# step financial balance (eur): -1266.653783399015 current_interest 1020.28217
#
#
# STEP: 12
# ACT
#  9
# OBS
#  [1.0250863  1.0201802  1.0290066  1.0329034  1.0259907  1.0201098
#  1.0248817  1.0143515  1.0209877  1.0242549  1.0191637  1.0250112
#  0.10041418 0.03064603 0.22538169 0.55399454 0.23676874 0.17549607
#  0.62133336]
# step financial balance (eur): -2833.4130375569584 current_interest 2211.2854
#
#
# STEP: 13
# ACT
#  3
# OBS
#  [1.0254594  1.0205139  1.0171506  1.0194783  1.0159808  1.0226579
#  1.0244921  1.0277653  1.0061955  1.0117717  1.0267699  1.0029215
#  0.09439804 0.02880992 0.22565722 0.55399454 0.09198666 0.08753966
#  0.44933334]
# step financial balance (eur): -1591.7363134544835 current_interest 754.9385
#
#
# STEP: 14
# ACT
#  12
# OBS
#  [1.0227656  1.0215082  1.0218426  1.0256137  1.0202459  1.0263505
#  1.0288148  1.0232095  1.0323592  1.030245   1.0166402  1.0259504
#  0.06033934 0.01841534 0.30871803 0.55399454 0.31712756 0.1817727
#  0.27066666]
# step financial balance (eur): -3154.644400265211 current_interest 2970.0813
#
#
# STEP: 15
# ACT
#  6
# OBS
#  [1.0430504  1.035269   1.0298827  1.0177939  1.0418582  1.0149053
#  1.0162016  1.037266   1.0268366  1.0239747  1.0462981  1.0220048
#  0.08155653 0.02489075 0.30871803 0.55399454 0.17818967 0.2223933
#  0.64533335]
# step financial balance (eur): -2630.3421885457647 current_interest 1439.836
#
#
# STEP: 16
# ACT
#  12
# OBS
#  [1.0486385  1.0398929  1.042224   1.0356888  1.033653   1.0429204
#  1.0366693  1.0296346  1.0429746  1.0299342  1.0440006  1.0391413
#  0.05950679 0.01816125 0.3087247  0.55399454 0.3173233  0.23428217
#  0.00266667]
# step financial balance (eur): -4268.574298012271 current_interest 2837.7483
#
#
# STEP: 17
# ACT
#  5
# OBS
#  [1.036526   1.0326786  1.0377034  1.0419409  1.0377038  1.0457093
#  1.038878   1.0390941  1.0365329  1.0439465  1.0313095  1.0343556
#  0.06393969 0.01951415 0.3087247  0.55399454 0.14832687 0.3039767
#  0.32133332]
# step financial balance (eur): -2749.9029068672417 current_interest 1114.3525
#
#
# STEP: 18
# ACT
#  2
# OBS
#  [1.0267597  1.0439322  1.0349423  1.0322303  1.0231243  1.0453255
#  1.0301434  1.0311557  1.0333053  1.029075   1.0406262  1.0251456
#  0.07898605 0.02410624 0.31029898 0.55399454 0.08493563 0.23055358
#  0.68      ]
# step financial balance (eur): -2661.5491668049035 current_interest 456.40323
#
#
# STEP: 19
# ACT
#  2
# OBS
#  [1.0172336  1.041019   1.0283724  1.0245379  1.038897   1.0380982
#  1.0242159  1.0172666  1.0253369  1.0300254  1.0304573  1.0453714
#  0.10808133 0.03298602 0.3131556  0.55399454 0.07861762 0.18794742
#  0.9573333 ]
# step financial balance (eur): -1963.2866504852914 current_interest 437.98715
#
#
# STEP: 20
# ACT
#  4
# OBS
#  [1.0342466  1.0441816  1.0269802  1.0345961  1.0310042  1.031363
#  1.0380073  1.0408133  1.0243446  1.0147431  1.0149034  1.0360318
#  0.117497   0.03585964 0.3132469  0.55399454 0.13562402 0.11075104
#  0.46      ]
# step financial balance (eur): -2093.771189587947 current_interest 857.8266
#
#
# STEP: 21
# ACT
#  6
# OBS
#  [1.0302365  1.0308547  1.0376185  1.030626   1.0421004  1.0394113
#  1.0239811  1.0443152  1.0326945  1.04792    1.0282136  1.0308405
#  0.13397121 0.04088751 0.31324774 0.55399454 0.17910585 0.06127988
#  0.82666665]
# step financial balance (eur): -1876.0787909074465 current_interest 1242.4235
#
#
# STEP: 22
# ACT
#  10
# OBS
#  [1.0368557  1.0394745  1.0354046  1.0416427  1.045391   1.0292655
#  1.0316889  1.0360543  1.0356303  1.0360452  1.034696   1.0434816
#  0.17778511 0.05425934 0.31444865 0.55399454 0.26952642 0.11709319
#  0.98      ]
# step financial balance (eur): -2324.6582444951614 current_interest 2005.9996
#
#
# STEP: 23
# ACT
#  0
# OBS
#  [1.0243045  1.0372611  1.0318646  1.0289776  1.0464853  1.0206892
#  1.0160342  1.0219319  1.0270875  1.0310309  1.0212611  1.0246369
#  0.18517421 0.05651447 0.31445023 0.55399454 0.03179029 0.12880251
#  0.524     ]
# step financial balance (eur): -257.93425268165856 current_interest 0.0
#
#
# STEP: 24
# ACT
#  3
# OBS
#  [1.0216564  1.0197705  1.022768   1.0121007  1.0426728  1.0452042
#  1.0389241  1.0230486  1.0176944  1.0222913  1.0345317  1.0125461
#  0.2037698  0.06218978 0.314451   0.55399454 0.10737188 0.1700576
#  0.47333333]
# step financial balance (eur): -1085.010064295076 current_interest 541.8927
#
#
# STEP: 25
# ACT
#  2
# OBS
#  [1.0097245  1.008113   1.0125988  1.0322164  1.0362839  1.0274159
#  1.0272189  1.0104989  1.0095675  1.0159085  1.026773   1.0430793
#  0.2037698  0.06218978 0.314451   0.55399454 0.08614699 0.04936699
#  0.588     ]
# step financial balance (eur): -1143.869754750287 current_interest 357.85577

# %%
test1(1000, env)
# Out:
# Episode:1 Reward:-2.2678364935212074
#
# total financial balance: (eur) -52614.09412582126
#
# internal rate of return 0
#
# net present value 0
#
# Episode:2 Reward:0.3065969720685957
#
# total financial balance: (eur) -46529.322686900065
#
# internal rate of return 0
#
# net present value 0
#
# Episode:3 Reward:-0.6831915351295504
#
# total financial balance: (eur) -32001.340258122935
#
# internal rate of return 0
#
# net present value 0
#
# Episode:4 Reward:-0.624197517041491
#
# total financial balance: (eur) -37697.550935301755
#
# internal rate of return 0
#
# net present value 0
#
# Episode:5 Reward:-2.38703202340475
#
# total financial balance: (eur) -43695.57355802166
#
# internal rate of return 0
#
# net present value 0
#
# Episode:6 Reward:-2.4397693076585503
#
# total financial balance: (eur) -49309.20520249589
#
# internal rate of return 0
#
# net present value 0
#
# Episode:7 Reward:-2.083883005157868
#
# total financial balance: (eur) -54005.33181469097
#
# internal rate of return 0
#
# net present value 0
#
# Episode:8 Reward:-1.4604813476548457
#
# total financial balance: (eur) -58889.482899054805
#
# internal rate of return 0
#
# net present value 0
#
# Episode:9 Reward:-1.4685396525216816
#
# total financial balance: (eur) -77386.6844099136
#
# internal rate of return 0
#
# net present value 0
#
# Episode:10 Reward:-1.4100873374928835
#
# total financial balance: (eur) -22877.178056754823
#
# internal rate of return 0
#
# net present value 0
#
# Episode:11 Reward:-2.54147678904321
#
# total financial balance: (eur) -50359.867327074586
#
# internal rate of return 0
#
# net present value 0
#
# Episode:12 Reward:-2.2518962482275473
#
# total financial balance: (eur) -40425.86659378761
#
# internal rate of return 0
#
# net present value 0
#
# Episode:13 Reward:-1.5223967076860034
#
# total financial balance: (eur) -34666.67157992991
#
# internal rate of return 0
#
# net present value 0
#
# Episode:14 Reward:-2.3470906440259696
#
# total financial balance: (eur) -50058.56725273697
#
# internal rate of return 0
#
# net present value 0
#
# Episode:15 Reward:-1.6821489570422974
#
# total financial balance: (eur) -38513.99993201663
#
# internal rate of return 0
#
# net present value 0
#
# Episode:16 Reward:-1.036372813554229
#
# total financial balance: (eur) -50267.700155205814
#
# internal rate of return 0
#
# net present value 0
#
# Episode:17 Reward:-1.623942512770448
#
# total financial balance: (eur) -52786.52637672304
#
# internal rate of return 0
#
# net present value 0
#
# Episode:18 Reward:-1.8194709618959273
#
# total financial balance: (eur) -72368.4687414407
#
# internal rate of return 0
#
# net present value 0
#
# Episode:19 Reward:-2.0111916803632295
#
# total financial balance: (eur) -47901.662860515964
#
# internal rate of return 0
#
# net present value 0
#
# Episode:20 Reward:-0.3910994754976064
#
# total financial balance: (eur) -35044.20349953236
#
# internal rate of return 0
#
# net present value 0
#
# Episode:21 Reward:-2.9737957278171008
#
# total financial balance: (eur) -56726.58419471327
#
# internal rate of return 0
#
# net present value 0
#
# Episode:22 Reward:-1.9785060319454577
#
# total financial balance: (eur) -35826.469509120594
#
# internal rate of return 0
#
# net present value 0
#
# Episode:23 Reward:-1.4383882121846314
#
# total financial balance: (eur) -41551.95124202525
#
# internal rate of return 0
#
# net present value 0
#
# Episode:24 Reward:-2.6347220539444525
#
# total financial balance: (eur) -49294.66262077722
#
# internal rate of return 0
#
# net present value 0
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_135932\3429799374.py:183: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
# Episode:25 Reward:-2.7387774546522183
#
# total financial balance: (eur) -52809.576056429476
#
# internal rate of return 0
#
# net present value 0
#
# Episode:26 Reward:-3.194054906384542
#
# total financial balance: (eur) -65120.90209334994
#
# internal rate of return 0
#
# net present value 0
#
# Episode:27 Reward:-0.7314948436469272
#
# total financial balance: (eur) -50972.139797717406
#
# internal rate of return 0
#
# net present value 0
#
# Episode:28 Reward:-2.927799461805512
#
# total financial balance: (eur) -38988.49454046207
#
# internal rate of return 0
#
# net present value 0
#
# Episode:29 Reward:-1.1832872127038492
#
# total financial balance: (eur) -57752.98687698972
#
# internal rate of return 0
#
# net present value 0
#
# Episode:30 Reward:-2.1128183935644818
#
# total financial balance: (eur) -71642.64371134402
#
# internal rate of return 0
#
# net present value 0
#
# Episode:31 Reward:-0.9410187812211889
#
# total financial balance: (eur) -66180.93775541613
#
# internal rate of return 0
#
# net present value 0
#
# Episode:32 Reward:-1.9542365627761993
#
# total financial balance: (eur) -52092.99566217706
#
# internal rate of return 0
#
# net present value 0
#
# Episode:33 Reward:-2.8725365180992632
#
# total financial balance: (eur) -64219.09194935541
#
# internal rate of return 0
#
# net present value 0
#
# Episode:34 Reward:-2.0681949097685046
#
# total financial balance: (eur) -47036.493428748494
#
# internal rate of return 0
#
# net present value 0
#
# Episode:35 Reward:-2.4349701571818776
#
# total financial balance: (eur) -51533.48568674951
#
# internal rate of return 0
#
# net present value 0
#
# Episode:36 Reward:-2.8567595198870834
#
# total financial balance: (eur) -64341.28412567364
#
# internal rate of return 0
#
# net present value 0
#
# Episode:37 Reward:-1.296822966859542
#
# total financial balance: (eur) -62485.602029465066
#
# internal rate of return 0
#
# net present value 0
#
# Episode:38 Reward:-2.02761778418476
#
# total financial balance: (eur) -38953.43046536372
#
# internal rate of return 0
#
# net present value 0
#
# Episode:39 Reward:-1.0223854831015922
#
# total financial balance: (eur) -30064.580295590487
#
# internal rate of return 0
#
# net present value 0
#
# Episode:40 Reward:-1.3433708672568085
#
# total financial balance: (eur) -46774.86563984212
#
# internal rate of return 0
#
# net present value 0
#
# Episode:41 Reward:-2.7516181964891815
#
# total financial balance: (eur) -53315.36948608446
#
# internal rate of return 0
#
# net present value 0
#
# Episode:42 Reward:-1.7975964394885389
#
# total financial balance: (eur) -41301.79794143295
#
# internal rate of return 0
#
# net present value 0
#
# Episode:43 Reward:-2.922753379113882
#
# total financial balance: (eur) -50496.09647136177
#
# internal rate of return 0
#
# net present value 0
#
# Episode:44 Reward:-1.7799514593547214
#
# total financial balance: (eur) -50140.4318471606
#
# internal rate of return 0
#
# net present value 0
#
# Episode:45 Reward:-1.8560572969864964
#
# total financial balance: (eur) -46083.79637104125
#
# internal rate of return 0
#
# net present value 0
#
# Episode:46 Reward:-2.5416291529728605
#
# total financial balance: (eur) -49095.86950561736
#
# internal rate of return 0
#
# net present value 0
#
# Episode:47 Reward:-1.0943615095891883
#
# total financial balance: (eur) -47042.6545544264
#
# internal rate of return 0
#
# net present value 0
#
# Episode:48 Reward:-2.4582661062058158
#
# total financial balance: (eur) -65740.71730812152
#
# internal rate of return 0
#
# net present value 0
#
# Episode:49 Reward:-0.5668686733582661
#
# total financial balance: (eur) -39397.74592610351
#
# internal rate of return 0
#
# net present value 0
#
# Episode:50 Reward:-2.0720029385432794
#
# total financial balance: (eur) -52448.07805263121
#
# internal rate of return 0
#
# net present value 0
#
# Episode:51 Reward:-2.5035086747444386
#
# total financial balance: (eur) -59963.53075253796
#
# internal rate of return 0
#
# net present value 0
#
# Episode:52 Reward:-2.1856166788305296
#
# total financial balance: (eur) -58222.31880563604
#
# internal rate of return 0
#
# net present value 0
#
# Episode:53 Reward:-3.3529289607841513
#
# total financial balance: (eur) -61302.48783556496
#
# internal rate of return 0
#
# net present value 0
#
# Episode:54 Reward:-3.8549234655351268
#
# total financial balance: (eur) -61935.531640594825
#
# internal rate of return 0
#
# net present value 0
#
# Episode:55 Reward:-2.1917803326316663
#
# total financial balance: (eur) -57783.357915121334
#
# internal rate of return 0
#
# net present value 0
#
# Episode:56 Reward:-3.7513417833051212
#
# total financial balance: (eur) -56900.650201785895
#
# internal rate of return 0
#
# net present value 0
#
# Episode:57 Reward:-4.160586017155571
#
# total financial balance: (eur) -64669.97194351019
#
# internal rate of return 0
#
# net present value 0
#
# Episode:58 Reward:-0.6007636709123407
#
# total financial balance: (eur) -46926.03524124206
#
# internal rate of return 0
#
# net present value 0
#
# Episode:59 Reward:-2.436582870364931
#
# total financial balance: (eur) -42009.255647004116
#
# internal rate of return 0
#
# net present value 0
#
# Episode:60 Reward:-1.133452962231038
#
# total financial balance: (eur) -59342.72735309584
#
# internal rate of return 0
#
# net present value 0
#
# Episode:61 Reward:-3.5776686931633237
#
# total financial balance: (eur) -70298.28545576423
#
# internal rate of return 0
#
# net present value 0
#
# Episode:62 Reward:-2.7739964820336254
#
# total financial balance: (eur) -71954.43988964296
#
# internal rate of return 0
#
# net present value 0
#
# Episode:63 Reward:-4.019684127812384
#
# total financial balance: (eur) -50997.92667037256
#
# internal rate of return 0
#
# net present value 0
#
# Episode:64 Reward:-2.202902457304735
#
# total financial balance: (eur) -52584.624356256776
#
# internal rate of return 0
#
# net present value 0
#
# Episode:65 Reward:-3.5308222138079666
#
# total financial balance: (eur) -54927.90596858762
#
# internal rate of return 0
#
# net present value 0
#
# Episode:66 Reward:-2.710428063173843
#
# total financial balance: (eur) -35033.553929677015
#
# internal rate of return 0
#
# net present value 0
#
# Episode:67 Reward:-1.0626064149370194
#
# total financial balance: (eur) -38650.911323444845
#
# internal rate of return 0
#
# net present value 0
#
# Episode:68 Reward:-2.954269090005656
#
# total financial balance: (eur) -49964.693685689745
#
# internal rate of return 0
#
# net present value 0
#
# Episode:69 Reward:-2.101527176718545
#
# total financial balance: (eur) -50023.58989989756
#
# internal rate of return 0
#
# net present value 0
#
# Episode:70 Reward:-4.061482601090462
#
# total financial balance: (eur) -53940.14983250243
#
# internal rate of return 0
#
# net present value 0
#
# Episode:71 Reward:-2.5857122913872748
#
# total financial balance: (eur) -67232.33065659844
#
# internal rate of return 0
#
# net present value 0
#
# Episode:72 Reward:-0.6113753762904641
#
# total financial balance: (eur) -51536.19547639648
#
# internal rate of return 0
#
# net present value 0
#
# Episode:73 Reward:-1.3322056767925328
#
# total financial balance: (eur) -56242.54203493592
#
# internal rate of return 0
#
# net present value 0
#
# Episode:74 Reward:-0.6978475850003335
#
# total financial balance: (eur) -46570.752387680666
#
# internal rate of return 0
#
# net present value 0
#
# Episode:75 Reward:-2.338293777597711
#
# total financial balance: (eur) -59654.4155623009
#
# internal rate of return 0
#
# net present value 0
#
# Episode:76 Reward:-1.347113056553375
#
# total financial balance: (eur) -58884.38887875923
#
# internal rate of return 0
#
# net present value 0
#
# Episode:77 Reward:-1.4772448626241153
#
# total financial balance: (eur) -63349.252851492995
#
# internal rate of return 0
#
# net present value 0
#
# Episode:78 Reward:1.3404553980943654
#
# total financial balance: (eur) -38272.349764053986
#
# internal rate of return 0
#
# net present value 0
#
# Episode:79 Reward:-3.4560034042593055
#
# total financial balance: (eur) -58137.494350835994
#
# internal rate of return 0
#
# net present value 0
#
# Episode:80 Reward:-2.9777232668493463
#
# total financial balance: (eur) -47201.21093624432
#
# internal rate of return 0
#
# net present value 0
#
# Episode:81 Reward:-2.3904287320349513
#
# total financial balance: (eur) -50377.023579445995
#
# internal rate of return 0
#
# net present value 0
#
# Episode:82 Reward:-2.6865099055656967
#
# total financial balance: (eur) -36498.15871187022
#
# internal rate of return 0
#
# net present value 0
#
# Episode:83 Reward:-1.0157473151442522
#
# total financial balance: (eur) -43590.6667559478
#
# internal rate of return 0
#
# net present value 0
#
# Episode:84 Reward:-1.294676576393299
#
# total financial balance: (eur) -50334.54009133712
#
# internal rate of return 0
#
# net present value 0
#
# Episode:85 Reward:-2.1657722922093825
#
# total financial balance: (eur) -48941.50252391037
#
# internal rate of return 0
#
# net present value 0
#
# Episode:86 Reward:-3.1690047845048586
#
# total financial balance: (eur) -54875.59703990045
#
# internal rate of return 0
#
# net present value 0
#
# Episode:87 Reward:-1.6653445681757044
#
# total financial balance: (eur) -60186.44430013347
#
# internal rate of return 0
#
# net present value 0
#
# Episode:88 Reward:-1.0222997204931048
#
# total financial balance: (eur) -41711.96710984746
#
# internal rate of return 0
#
# net present value 0
#
# Episode:89 Reward:-1.8136603764852766
#
# total financial balance: (eur) -41551.98103984295
#
# internal rate of return 0
#
# net present value 0
# Episode:90 Reward:-2.970845994032722
#
# total financial balance: (eur) -34524.31827737688
#
# internal rate of return 0
#
# net present value 0
#
# Episode:91 Reward:-2.5873651123379973
#
# total financial balance: (eur) -62526.549813246966
#
# internal rate of return 0
#
# net present value 0
#
# Episode:92 Reward:-3.005976914731708
#
# total financial balance: (eur) -55494.666158220185
#
# internal rate of return 0
#
# net present value 0
#
# Episode:93 Reward:-1.230497134310356
#
# total financial balance: (eur) -43333.733824747615
#
# internal rate of return 0
#
# net present value 0
#
# Episode:94 Reward:-2.654814590775424
#
# total financial balance: (eur) -53541.749341634626
#
# internal rate of return 0
#
# net present value 0
#
# Episode:95 Reward:-0.563277772017332
#
# total financial balance: (eur) -27886.111773211273
#
# internal rate of return 0
#
# net present value 0
#
# Episode:96 Reward:-0.015402308475265044
#
# total financial balance: (eur) -35554.65438048335
#
# internal rate of return 0
#
# net present value 0
#
# Episode:97 Reward:-0.9782757696366777
#
# total financial balance: (eur) -37196.814751721475
#
# internal rate of return 0
#
# net present value 0
#
# Episode:98 Reward:-2.283426692128231
#
# total financial balance: (eur) -51673.096004384824
#
# internal rate of return 0
#
# net present value 0
#
# Episode:99 Reward:-0.9949221588928453
#
# total financial balance: (eur) -36559.71755944985
#
# internal rate of return 0
#
# net present value 0
#
# Episode:100 Reward:-1.9946383257681755
#
# total financial balance: (eur) -43305.70165885956
#
# internal rate of return 0
#
# net present value 0
#
# Episode:101 Reward:-0.7092544290885069
#
# total financial balance: (eur) -22338.8300157828
#
# internal rate of return 0
#
# net present value 0
#
# Episode:102 Reward:-2.403692685674376
#
# total financial balance: (eur) -59842.1907908879
#
# internal rate of return 0
#
# net present value 0
#
# Episode:103 Reward:-1.7573993719719678
#
# total financial balance: (eur) -47759.04097316221
#
# internal rate of return 0
#
# net present value 0
#
# Episode:104 Reward:-4.499788656054313
#
# total financial balance: (eur) -58518.16602618422
#
# internal rate of return 0
#
# net present value 0
#
# Episode:105 Reward:0.841517930244625
#
# total financial balance: (eur) -43419.77402053127
#
# internal rate of return 0
#
# net present value 0
#
# Episode:106 Reward:-2.917029964796072
#
# total financial balance: (eur) -43638.77619071192
#
# internal rate of return 0
#
# net present value 0
#
# Episode:107 Reward:-2.240599212491665
#
# total financial balance: (eur) -51820.20709490942
#
# internal rate of return 0
#
# net present value 0
#
# Episode:108 Reward:0.18575124283405456
#
# total financial balance: (eur) -41794.29445482439
#
# internal rate of return 0
#
# net present value 0
#
# Episode:109 Reward:-1.0485670793360502
#
# total financial balance: (eur) -46553.46069087522
#
# internal rate of return 0
#
# net present value 0
#
# Episode:110 Reward:0.3138211516790957
#
# total financial balance: (eur) -28715.178319171187
#
# internal rate of return 0
#
# net present value 0
#
# Episode:111 Reward:-2.0360550839367577
#
# total financial balance: (eur) -54404.29800206262
#
# internal rate of return 0
#
# net present value 0
#
# Episode:112 Reward:-2.2339760447485757
#
# total financial balance: (eur) -52578.39302621927
#
# internal rate of return 0
#
# net present value 0
#
# Episode:113 Reward:-3.037618912469745
#
# total financial balance: (eur) -46523.8492935352
#
# internal rate of return 0
#
# net present value 0
#
# Episode:114 Reward:-0.7906704959305871
#
# total financial balance: (eur) -43176.68166885699
#
# internal rate of return 0
#
# net present value 0
#
# Episode:115 Reward:-3.609490231678259
#
# total financial balance: (eur) -64715.22807965085
#
# internal rate of return 0
#
# net present value 0
#
# Episode:116 Reward:-1.3282195145733287
#
# total financial balance: (eur) -42181.0496429211
#
# internal rate of return 0
#
# net present value 0
#
# Episode:117 Reward:-1.511057762755744
#
# total financial balance: (eur) -38525.54000191863
#
# internal rate of return 0
#
# net present value 0
#
# Episode:118 Reward:-1.0123581449047667
#
# total financial balance: (eur) -65069.59839411419
#
# internal rate of return 0
#
# net present value 0
#
# Episode:119 Reward:-4.049261643004049
#
# total financial balance: (eur) -78149.5709082668
#
# internal rate of return 0
#
# net present value 0
#
# Episode:120 Reward:-2.676513118321607
#
# total financial balance: (eur) -52502.64046780659
#
# internal rate of return 0
#
# net present value 0
#
# Episode:121 Reward:-2.2328464821167326
#
# total financial balance: (eur) -38786.98473217111
#
# internal rate of return 0
#
# net present value 0
#
# Episode:122 Reward:-2.608627128539684
#
# total financial balance: (eur) -56041.53392239105
#
# internal rate of return 0
#
# net present value 0
#
# Episode:123 Reward:-2.6858674184792637
#
# total financial balance: (eur) -55878.674103732556
#
# internal rate of return 0
#
# net present value 0
#
# Episode:124 Reward:-2.960547194033423
#
# total financial balance: (eur) -56837.239234732486
#
# internal rate of return 0
#
# net present value 0
#
# Episode:125 Reward:-2.0895812889446352
#
# total financial balance: (eur) -49091.564686605634
#
# internal rate of return 0
#
# net present value 0
#
# Episode:126 Reward:-2.127408670346499
#
# total financial balance: (eur) -60677.014548950196
#
# internal rate of return 0
#
# net present value 0
#
# Episode:127 Reward:-2.835412636612109
#
# total financial balance: (eur) -42130.509595245414
#
# internal rate of return 0
#
# net present value 0
#
# Episode:128 Reward:-1.260884801860675
#
# total financial balance: (eur) -51605.44090002484
#
# internal rate of return 0
#
# net present value 0
#
# Episode:129 Reward:-2.1580341469101305
#
# total financial balance: (eur) -57650.90835399573
#
# internal rate of return 0
#
# net present value 0
#
# Episode:130 Reward:-2.9240558201969553
#
# total financial balance: (eur) -59138.55375093127
#
# internal rate of return 0
#
# net present value 0
#
# Episode:131 Reward:-3.265335465044798
#
# total financial balance: (eur) -56766.229674122704
#
# internal rate of return 0
#
# net present value 0
#
# Episode:132 Reward:-1.5091700658530165
#
# total financial balance: (eur) -45701.50971432268
#
# internal rate of return 0
#
# net present value 0
#
# Episode:133 Reward:-2.2922245758819293
#
# total financial balance: (eur) -52519.880744604576
#
# internal rate of return 0
#
# net present value 0
#
# Episode:134 Reward:-0.6455508622644188
#
# total financial balance: (eur) -40113.88402750405
#
# internal rate of return 0
#
# net present value 0
#
# Episode:135 Reward:-2.764537927838627
#
# total financial balance: (eur) -53899.13550815257
#
# internal rate of return 0
#
# net present value 0
#
# Episode:136 Reward:-3.105886011117629
#
# total financial balance: (eur) -57424.29992634739
#
# internal rate of return 0
#
# net present value 0
#
# Episode:137 Reward:-0.802912638313692
#
# total financial balance: (eur) -41936.2010464972
#
# internal rate of return 0
#
# net present value 0
#
# Episode:138 Reward:-1.4084418088215305
#
# total financial balance: (eur) -50830.26725929964
#
# internal rate of return 0
#
# net present value 0
#
# Episode:139 Reward:-0.5095762283345473
#
# total financial balance: (eur) -31791.868534362762
#
# internal rate of return 0
#
# net present value 0
#
# Episode:140 Reward:-0.5970841128294995
#
# total financial balance: (eur) -54530.21023446347
#
# internal rate of return 0
#
# net present value 0
#
# Episode:141 Reward:0.010944791031945896
#
# total financial balance: (eur) -57929.80363448326
#
# internal rate of return 0
#
# net present value 0
#
# Episode:142 Reward:-1.1491255557323827
#
# total financial balance: (eur) -32371.35808195147
#
# internal rate of return 0
#
# net present value 0
#
# Episode:143 Reward:-1.8005222074161054
#
# total financial balance: (eur) -57371.692072962294
#
# internal rate of return 0
#
# net present value 0
#
# Episode:144 Reward:-0.12397762706673461
#
# total financial balance: (eur) -48936.140089777444
#
# internal rate of return 0
#
# net present value 0
#
# Episode:145 Reward:-1.485934642666583
#
# total financial balance: (eur) -39117.66212615469
#
# internal rate of return 0
#
# net present value 0
#
# Episode:146 Reward:-2.711822596296936
#
# total financial balance: (eur) -55517.380051738044
#
# internal rate of return 0
#
# net present value 0
#
# Episode:147 Reward:-0.844542838578687
#
# total financial balance: (eur) -31898.04085846162
#
# internal rate of return 0
#
# net present value 0
#
# Episode:148 Reward:-3.1056801472377265
#
# total financial balance: (eur) -56275.33687478863
#
# internal rate of return 0
#
# net present value 0
#
# Episode:149 Reward:-3.936604460457951
#
# total financial balance: (eur) -48719.7388402584
#
# internal rate of return 0
#
# net present value 0
#
# Episode:150 Reward:-1.513653779756721
#
# total financial balance: (eur) -43713.43791235709
#
# internal rate of return 0
#
# net present value 0
#
# Episode:151 Reward:-0.7434979516954522
#
# total financial balance: (eur) -40688.13228384914
#
# internal rate of return 0
#
# net present value 0
#
# Episode:152 Reward:-2.7911871408451785
#
# total financial balance: (eur) -52219.62389169337
#
# internal rate of return 0
#
# net present value 0
#
# Episode:153 Reward:-2.0661991986200987
#
# total financial balance: (eur) -51514.23030558069
#
# internal rate of return 0
#
# net present value 0
#
# Episode:154 Reward:-1.6176000864314637
#
# total financial balance: (eur) -54536.08684676152
#
# internal rate of return 0
#
# net present value 0
#
# Episode:155 Reward:-0.7943997880107895
#
# total financial balance: (eur) -58759.3753849382
#
# internal rate of return 0
#
# net present value 0
#
# Episode:156 Reward:-0.93669011316443
#
# total financial balance: (eur) -37635.67959824782
#
# internal rate of return 0
#
# net present value 0
#
# Episode:157 Reward:-3.2013373513770222
#
# total financial balance: (eur) -56357.38070379235
#
# internal rate of return 0
#
# net present value 0
#
# Episode:158 Reward:-0.14960692057592337
#
# total financial balance: (eur) -47799.84831727132
#
# internal rate of return 0
#
# net present value 0
# Episode:159 Reward:-1.7187719826850814
#
# total financial balance: (eur) -52981.41009581659
#
# internal rate of return 0
#
# net present value 0
#
# Episode:160 Reward:-2.345973792729332
#
# total financial balance: (eur) -49914.507712245395
#
# internal rate of return 0
#
# net present value 0
#
# Episode:161 Reward:-2.8872211430110766
#
# total financial balance: (eur) -39925.3243842678
#
# internal rate of return 0
#
# net present value 0
#
# Episode:162 Reward:-1.9696082918882092
#
# total financial balance: (eur) -33656.31659986398
#
# internal rate of return 0
#
# net present value 0
#
# Episode:163 Reward:-3.845182924508904
#
# total financial balance: (eur) -59368.92240241868
#
# internal rate of return 0
#
# net present value 0
#
# Episode:164 Reward:-0.49567321919121377
#
# total financial balance: (eur) -35447.638350067136
#
# internal rate of return 0
#
# net present value 0
#
# Episode:165 Reward:-1.9629054823552146
#
# total financial balance: (eur) -39269.616297563036
#
# internal rate of return 0
#
# net present value 0
#
# Episode:166 Reward:-1.0812433474556005
#
# total financial balance: (eur) -49935.89814585331
#
# internal rate of return 0
#
# net present value 0
#
# Episode:167 Reward:-0.70588986187
#
# total financial balance: (eur) -45709.8769201367
#
# internal rate of return 0
#
# net present value 0
#
# Episode:168 Reward:-0.31449114764964814
#
# total financial balance: (eur) -53567.850937227064
#
# internal rate of return 0
#
# net present value 0
#
# Episode:169 Reward:-2.882691597637181
#
# total financial balance: (eur) -42707.00157346186
#
# internal rate of return 0
#
# net present value 0
#
# Episode:170 Reward:-2.7052350741888325
#
# total financial balance: (eur) -53498.899651937245
#
# internal rate of return 0
#
# net present value 0
#
# Episode:171 Reward:-0.057435582027703276
#
# total financial balance: (eur) -26339.54076474627
#
# internal rate of return 0
#
# net present value 0
#
# Episode:172 Reward:-0.9490353549269144
#
# total financial balance: (eur) -60219.12932914366
#
# internal rate of return 0
#
# net present value 0
#
# Episode:173 Reward:-1.5355411142076572
#
# total financial balance: (eur) -36723.95216749955
#
# internal rate of return 0
#
# net present value 0
#
# Episode:174 Reward:-2.709342314209837
#
# total financial balance: (eur) -63069.84973828622
#
# internal rate of return 0
#
# net present value 0
#
# Episode:175 Reward:-0.9133941854497948
#
# total financial balance: (eur) -59760.605556920294
#
# internal rate of return 0
#
# net present value 0
#
# Episode:176 Reward:-1.7816135383189695
#
# total financial balance: (eur) -33711.34672320734
#
# internal rate of return 0
#
# net present value 0
#
# Episode:177 Reward:-1.915365318227762
#
# total financial balance: (eur) -43252.87857045446
#
# internal rate of return 0
#
# net present value 0
#
# Episode:178 Reward:-1.9255344040907745
#
# total financial balance: (eur) -51922.63018399685
#
# internal rate of return 0
#
# net present value 0
#
# Episode:179 Reward:-1.5704038267218376
#
# total financial balance: (eur) -46772.57163930207
#
# internal rate of return 0
#
# net present value 0
#
# Episode:180 Reward:-1.814134855675141
#
# total financial balance: (eur) -64790.27587689374
#
# internal rate of return 0
#
# net present value 0
#
# Episode:181 Reward:-2.122917308316609
#
# total financial balance: (eur) -62583.467470312025
#
# internal rate of return 0
#
# net present value 0
#
# Episode:182 Reward:-1.6044269030825058
#
# total financial balance: (eur) -50010.7034856057
#
# internal rate of return 0
#
# net present value 0
#
# Episode:183 Reward:-0.8419740489458336
#
# total financial balance: (eur) -42775.80065882842
#
# internal rate of return 0
#
# net present value 0
#
# Episode:184 Reward:-0.9637189409187648
#
# total financial balance: (eur) -24892.011416246532
#
# internal rate of return 0
#
# net present value 0
#
# Episode:185 Reward:-3.5100630097652155
#
# total financial balance: (eur) -56626.30423301213
#
# internal rate of return 0
#
# net present value 0
#
# Episode:186 Reward:-1.6978541770101694
#
# total financial balance: (eur) -42976.830452921226
#
# internal rate of return 0
#
# net present value 0
#
# Episode:187 Reward:-2.8841508030666088
#
# total financial balance: (eur) -36656.318185904434
#
# internal rate of return 0
#
# net present value 0
#
# Episode:188 Reward:-1.67045031057018
#
# total financial balance: (eur) -52615.60734363782
#
# internal rate of return 0
#
# net present value 0
#
# Episode:189 Reward:-1.3021268212322425
#
# total financial balance: (eur) -62949.89561273696
#
# internal rate of return 0
#
# net present value 0
#
# Episode:190 Reward:-0.513042281526004
#
# total financial balance: (eur) -31570.350152939867
#
# internal rate of return 0
#
# net present value 0
#
# Episode:191 Reward:-3.4592409412746528
#
# total financial balance: (eur) -69345.46640610506
#
# internal rate of return 0
#
# net present value 0
#
# Episode:192 Reward:-3.799050018644287
#
# total financial balance: (eur) -44128.96051199513
#
# internal rate of return 0
#
# net present value 0
#
# Episode:193 Reward:-0.5448307282904088
#
# total financial balance: (eur) -41795.71800265053
#
# internal rate of return 0
#
# net present value 0
#
# Episode:194 Reward:-2.703381064697439
#
# total financial balance: (eur) -62057.03278171404
#
# internal rate of return 0
#
# net present value 0
#
# Episode:195 Reward:-2.943773123122241
#
# total financial balance: (eur) -67483.75752504304
#
# internal rate of return 0
#
# net present value 0
#
# Episode:196 Reward:-2.9467719624416304
#
# total financial balance: (eur) -49270.05809209744
#
# internal rate of return 0
#
# net present value 0
#
# Episode:197 Reward:-1.8743499245270412
#
# total financial balance: (eur) -43615.631481063334
#
# internal rate of return 0
#
# net present value 0
#
# Episode:198 Reward:-2.1835786541212827
#
# total financial balance: (eur) -66384.27124861689
#
# internal rate of return 0
#
# net present value 0
#
# Episode:199 Reward:-2.34175563118348
#
# total financial balance: (eur) -38040.85110617968
#
# internal rate of return 0
#
# net present value 0
#
# Episode:200 Reward:-1.3127890945131908
#
# total financial balance: (eur) -45407.44289716594
#
# internal rate of return 0
#
# net present value 0
#
# Episode:201 Reward:-1.9717357035793326
#
# total financial balance: (eur) -36941.952476981205
#
# internal rate of return 0
#
# net present value 0
#
# Episode:202 Reward:-2.5474531715062185
#
# total financial balance: (eur) -58654.05434830995
#
# internal rate of return 0
#
# net present value 0
#
# Episode:203 Reward:-0.12446601311336145
#
# total financial balance: (eur) -41962.945939379606
#
# internal rate of return 0
#
# net present value 0
#
# Episode:204 Reward:-2.632409192946013
#
# total financial balance: (eur) -45698.2510325437
#
# internal rate of return 0
#
# net present value 0
#
# Episode:205 Reward:-1.8050529227246013
#
# total financial balance: (eur) -52946.88132862058
#
# internal rate of return 0
#
# net present value 0
#
# Episode:206 Reward:-1.9020636998754947
#
# total financial balance: (eur) -60948.910508138884
#
# internal rate of return 0
#
# net present value 0
#
# Episode:207 Reward:-2.963845586341622
#
# total financial balance: (eur) -42354.66040721486
#
# internal rate of return 0
#
# net present value 0
#
# Episode:208 Reward:-0.36120366716747615
#
# total financial balance: (eur) -52964.77449372442
#
# internal rate of return 0
#
# net present value 0
#
# Episode:209 Reward:-1.330005611887634
#
# total financial balance: (eur) -41311.22484881978
#
# internal rate of return 0
#
# net present value 0
#
# Episode:210 Reward:-2.4648020742884866
#
# total financial balance: (eur) -50647.39637606695
#
# internal rate of return 0
#
# net present value 0
#
# Episode:211 Reward:0.37646955226469253
#
# total financial balance: (eur) -46637.01031789786
#
# internal rate of return 0
#
# net present value 0
#
# Episode:212 Reward:0.3046035346715403
#
# total financial balance: (eur) -39121.57803789707
#
# internal rate of return 0
#
# net present value 0
#
# Episode:213 Reward:-2.371226987539599
#
# total financial balance: (eur) -37411.4760288826
#
# internal rate of return 0
#
# net present value 0
#
# Episode:214 Reward:-2.709599876327816
#
# total financial balance: (eur) -43328.38794607665
#
# internal rate of return 0
#
# net present value 0
#
# Episode:215 Reward:-0.850175887903001
#
# total financial balance: (eur) -47024.259964867786
#
# internal rate of return 0
#
# net present value 0
#
# Episode:216 Reward:-2.843653519001102
#
# total financial balance: (eur) -55507.950085304794
#
# internal rate of return 0
#
# net present value 0
#
# Episode:217 Reward:-3.538535079455093
#
# total financial balance: (eur) -43543.54348037903
#
# internal rate of return 0
#
# net present value 0
#
# Episode:218 Reward:-1.6393265214768773
#
# total financial balance: (eur) -50951.6708639141
#
# internal rate of return 0
#
# net present value 0
#
# Episode:219 Reward:-1.993393788113002
#
# total financial balance: (eur) -51402.6934313018
#
# internal rate of return 0
#
# net present value 0
#
# Episode:220 Reward:-2.7918032253597884
#
# total financial balance: (eur) -58822.9967650984
#
# internal rate of return 0
#
# net present value 0
#
# Episode:221 Reward:-2.783941758642099
#
# total financial balance: (eur) -70692.8568596015
#
# internal rate of return 0
#
# net present value 0
#
# Episode:222 Reward:-2.9732713591505915
#
# total financial balance: (eur) -59617.4226027217
#
# internal rate of return 0
#
# net present value 0
#
# Episode:223 Reward:-1.1724882209608356
#
# total financial balance: (eur) -54519.89141878501
#
# internal rate of return 0
#
# net present value 0
#
# Episode:224 Reward:-1.496685009214326
#
# total financial balance: (eur) -44086.94862892994
#
# internal rate of return 0
#
# net present value 0
#
# Episode:225 Reward:-0.22419489631499573
#
# total financial balance: (eur) -63812.15247184773
#
# internal rate of return 0
#
# net present value 0
#
# Episode:226 Reward:-3.019126595316058
#
# total financial balance: (eur) -60440.700313256864
#
# internal rate of return 0
#
# net present value 0
#
# Episode:227 Reward:-2.324059755441187
#
# total financial balance: (eur) -50646.2243407516
#
# internal rate of return 0
#
# net present value 0
#
# Episode:228 Reward:-2.3763040301185363
#
# total financial balance: (eur) -51396.086418414925
#
# internal rate of return 0
#
# net present value 0
#
# Episode:229 Reward:-3.922056364882061
#
# total financial balance: (eur) -53735.4710859709
#
# internal rate of return 0
#
# net present value 0
#
# Episode:230 Reward:-1.9423652072024322
#
# total financial balance: (eur) -57630.08162485498
#
# internal rate of return 0
#
# net present value 0
# Episode:231 Reward:-1.9132193476587933
#
# total financial balance: (eur) -51593.964572727484
#
# internal rate of return 0
#
# net present value 0
#
# Episode:232 Reward:0.2748308732835358
#
# total financial balance: (eur) -26552.325192975273
#
# internal rate of return 0
#
# net present value 0
#
# Episode:233 Reward:-2.1700418065186513
#
# total financial balance: (eur) -40292.51043996196
#
# internal rate of return 0
#
# net present value 0
#
# Episode:234 Reward:-0.4240524556616049
#
# total financial balance: (eur) -41605.94000515174
#
# internal rate of return 0
#
# net present value 0
#
# Episode:235 Reward:-2.6866907404632903
#
# total financial balance: (eur) -40938.18398040889
#
# internal rate of return 0
#
# net present value 0
#
# Episode:236 Reward:-0.6508611629151797
#
# total financial balance: (eur) -55361.96165807137
#
# internal rate of return 0
#
# net present value 0
#
# Episode:237 Reward:-1.5099430548069936
#
# total financial balance: (eur) -49761.26050516798
#
# internal rate of return 0
#
# net present value 0
#
# Episode:238 Reward:-1.941480495336244
#
# total financial balance: (eur) -50577.11171445604
#
# internal rate of return 0
#
# net present value 0
#
# Episode:239 Reward:-3.6570603160618993
#
# total financial balance: (eur) -42850.63946336802
#
# internal rate of return 0
#
# net present value 0
#
# Episode:240 Reward:-1.511959519059631
#
# total financial balance: (eur) -44926.11532724587
#
# internal rate of return 0
#
# net present value 0
#
# Episode:241 Reward:-1.9643871622891165
#
# total financial balance: (eur) -50303.130093500855
#
# internal rate of return 0
#
# net present value 0
#
# Episode:242 Reward:-0.6894378899783978
#
# total financial balance: (eur) -42342.04867118033
#
# internal rate of return 0
#
# net present value 0
#
# Episode:243 Reward:-0.5569694032444875
#
# total financial balance: (eur) -58963.8638262679
#
# internal rate of return 0
#
# net present value 0
#
# Episode:244 Reward:-2.5085475371097834
#
# total financial balance: (eur) -47513.06823704942
#
# internal rate of return 0
#
# net present value 0
#
# Episode:245 Reward:-1.8685607471302383
#
# total financial balance: (eur) -56902.919144453954
#
# internal rate of return 0
#
# net present value 0
#
# Episode:246 Reward:-1.6264500792560317
#
# total financial balance: (eur) -31964.06861888009
#
# internal rate of return 0
#
# net present value 0
#
# Episode:247 Reward:-2.8899678013826904
#
# total financial balance: (eur) -48551.44097867375
#
# internal rate of return 0
#
# net present value 0
#
# Episode:248 Reward:-3.5388330401279213
#
# total financial balance: (eur) -52870.99242367868
#
# internal rate of return 0
#
# net present value 0
#
# Episode:249 Reward:-0.4318592009206718
#
# total financial balance: (eur) -56978.26499603831
#
# internal rate of return 0
#
# net present value 0
#
# Episode:250 Reward:-2.333850886232892
#
# total financial balance: (eur) -50135.92127926629
#
# internal rate of return 0
#
# net present value 0
#
# Episode:251 Reward:-1.8129430472885664
#
# total financial balance: (eur) -45033.50346212687
#
# internal rate of return 0
#
# net present value 0
#
# Episode:252 Reward:-0.5538486415085537
#
# total financial balance: (eur) -51976.44920980616
#
# internal rate of return 0
#
# net present value 0
#
# Episode:253 Reward:0.17651661457899512
#
# total financial balance: (eur) -41367.72468092206
#
# internal rate of return 0
#
# net present value 0
#
# Episode:254 Reward:-2.75215711496788
#
# total financial balance: (eur) -60469.35300806136
#
# internal rate of return 0
#
# net present value 0
#
# Episode:255 Reward:-2.053090366492949
#
# total financial balance: (eur) -45478.12841822104
#
# internal rate of return 0
#
# net present value 0
#
# Episode:256 Reward:-2.0028143060909462
#
# total financial balance: (eur) -48656.429545468854
#
# internal rate of return 0
#
# net present value 0
#
# Episode:257 Reward:-2.6155618105335634
#
# total financial balance: (eur) -63127.116483218255
#
# internal rate of return 0
#
# net present value 0
#
# Episode:258 Reward:-3.2367457044579626
#
# total financial balance: (eur) -41947.36339579777
#
# internal rate of return 0
#
# net present value 0
#
# Episode:259 Reward:-1.0707563067478896
#
# total financial balance: (eur) -31849.630480567466
#
# internal rate of return 0
#
# net present value 0
#
# Episode:260 Reward:-0.13612590139866404
#
# total financial balance: (eur) -47230.77383497092
#
# internal rate of return 0
#
# net present value 0
#
# Episode:261 Reward:-1.6974232088185786
#
# total financial balance: (eur) -48219.052127273746
#
# internal rate of return 0
#
# net present value 0
#
# Episode:262 Reward:-1.554383147831774
#
# total financial balance: (eur) -50588.95266299192
#
# internal rate of return 0
#
# net present value 0
#
# Episode:263 Reward:-2.9734981853562124
#
# total financial balance: (eur) -46891.70664690647
#
# internal rate of return 0
#
# net present value 0
#
# Episode:264 Reward:-0.0733857712364254
#
# total financial balance: (eur) -38507.709933433034
#
# internal rate of return 0
#
# net present value 0
#
# Episode:265 Reward:-1.5240804065375673
#
# total financial balance: (eur) -52235.49012897
#
# internal rate of return 0
#
# net present value 0
#
# Episode:266 Reward:-3.276758892235963
#
# total financial balance: (eur) -64907.359009300104
#
# internal rate of return 0
#
# net present value 0
#
# Episode:267 Reward:-0.030410094956682315
#
# total financial balance: (eur) -54359.87079021534
#
# internal rate of return 0
#
# net present value 0
#
# Episode:268 Reward:-1.5172951655810776
#
# total financial balance: (eur) -52613.285667912045
#
# internal rate of return 0
#
# net present value 0
#
# Episode:269 Reward:-1.3911190637484925
#
# total financial balance: (eur) -52486.81774214001
#
# internal rate of return 0
#
# net present value 0
#
# Episode:270 Reward:-3.0615965755538554
#
# total financial balance: (eur) -39546.792444501705
#
# internal rate of return 0
#
# net present value 0
#
# Episode:271 Reward:-2.073626275054303
#
# total financial balance: (eur) -50195.02599160945
#
# internal rate of return 0
#
# net present value 0
#
# Episode:272 Reward:-3.037371987160286
#
# total financial balance: (eur) -57460.756562991526
#
# internal rate of return 0
#
# net present value 0
#
# Episode:273 Reward:-1.6111198156958104
#
# total financial balance: (eur) -49611.67296703821
#
# internal rate of return 0
#
# net present value 0
#
# Episode:274 Reward:0.014396516046299894
#
# total financial balance: (eur) -58345.89110511129
#
# internal rate of return 0
#
# net present value 0
#
# Episode:275 Reward:-1.34884040064171
#
# total financial balance: (eur) -44704.9313489078
#
# internal rate of return 0
#
# net present value 0
#
# Episode:276 Reward:-3.389939892906993
#
# total financial balance: (eur) -50278.14337765729
#
# internal rate of return 0
#
# net present value 0
#
# Episode:277 Reward:-2.2512436409672056
#
# total financial balance: (eur) -53398.784645064414
#
# internal rate of return 0
#
# net present value 0
#
# Episode:278 Reward:-1.909631719938856
#
# total financial balance: (eur) -52679.09275832926
#
# internal rate of return 0
#
# net present value 0
#
# Episode:279 Reward:-2.489115225027284
#
# total financial balance: (eur) -67098.2943735935
#
# internal rate of return 0
#
# net present value 0
#
# Episode:280 Reward:-2.69027113870968
#
# total financial balance: (eur) -60919.435358619055
#
# internal rate of return 0
#
# net present value 0
#
# Episode:281 Reward:-2.5746607890685547
#
# total financial balance: (eur) -57900.668865731175
#
# internal rate of return 0
#
# net present value 0
#
# Episode:282 Reward:-2.6925870795142135
#
# total financial balance: (eur) -64215.69843302078
#
# internal rate of return 0
#
# net present value 0
#
# Episode:283 Reward:-2.0432043888357945
#
# total financial balance: (eur) -57209.23829147373
#
# internal rate of return 0
#
# net present value 0
#
# Episode:284 Reward:-3.9313866928636116
#
# total financial balance: (eur) -45619.232523386956
#
# internal rate of return 0
#
# net present value 0
#
# Episode:285 Reward:-1.1871602590580128
#
# total financial balance: (eur) -47762.75843613302
#
# internal rate of return 0
#
# net present value 0
#
# Episode:286 Reward:-1.2510254556623717
#
# total financial balance: (eur) -44399.89255179526
#
# internal rate of return 0
#
# net present value 0
#
# Episode:287 Reward:-1.4964162515822994
#
# total financial balance: (eur) -43781.760399845836
#
# internal rate of return 0
#
# net present value 0
#
# Episode:288 Reward:-2.851302363146451
#
# total financial balance: (eur) -52953.94294030073
#
# internal rate of return 0
#
# net present value 0
#
# Episode:289 Reward:-2.6066778556902874
#
# total financial balance: (eur) -55225.51265958847
#
# internal rate of return 0
#
# net present value 0
#
# Episode:290 Reward:-2.449801245397561
#
# total financial balance: (eur) -45591.15539640851
#
# internal rate of return 0
#
# net present value 0
#
# Episode:291 Reward:-2.2176713180417194
#
# total financial balance: (eur) -61374.121629194466
#
# internal rate of return 0
#
# net present value 0
#
# Episode:292 Reward:-1.3351833133080504
#
# total financial balance: (eur) -58151.49767122856
#
# internal rate of return 0
#
# net present value 0
#
# Episode:293 Reward:-0.8305161905551985
#
# total financial balance: (eur) -40510.46784315673
#
# internal rate of return 0
#
# net present value 0
#
# Episode:294 Reward:-1.7392534668831614
#
# total financial balance: (eur) -45408.08512289818
#
# internal rate of return 0
#
# net present value 0
#
# Episode:295 Reward:-0.598419953820566
#
# total financial balance: (eur) -49646.6033944269
#
# internal rate of return 0
#
# net present value 0
#
# Episode:296 Reward:-0.5693013137505791
#
# total financial balance: (eur) -49414.24011631607
#
# internal rate of return 0
#
# net present value 0
#
# Episode:297 Reward:-3.8328901362257337
#
# total financial balance: (eur) -54759.16779198683
#
# internal rate of return 0
#
# net present value 0
#
# Episode:298 Reward:-3.003959708852095
#
# total financial balance: (eur) -56464.244197020445
#
# internal rate of return 0
#
# net present value 0
#
# Episode:299 Reward:-2.9760543751234954
#
# total financial balance: (eur) -47210.45328667258
#
# internal rate of return 0
#
# net present value 0
#
# Episode:300 Reward:-2.2233923983414305
#
# total financial balance: (eur) -38899.381186759114
#
# internal rate of return 0
#
# net present value 0
#
# Episode:301 Reward:-1.3171606770927937
#
# total financial balance: (eur) -52468.21243125707
#
# internal rate of return 0
#
# net present value 0
# Episode:302 Reward:-2.530843308461159
#
# total financial balance: (eur) -54606.8421295095
#
# internal rate of return 0
#
# net present value 0
#
# Episode:303 Reward:-1.1766849089629596
#
# total financial balance: (eur) -45340.373345461434
#
# internal rate of return 0
#
# net present value 0
#
# Episode:304 Reward:-2.328658207604313
#
# total financial balance: (eur) -46596.52570161726
#
# internal rate of return 0
#
# net present value 0
#
# Episode:305 Reward:-1.6669838407575364
#
# total financial balance: (eur) -44763.57104993845
#
# internal rate of return 0
#
# net present value 0
#
# Episode:306 Reward:-2.0496977206519094
#
# total financial balance: (eur) -78433.56836367815
#
# internal rate of return 0
#
# net present value 0
#
# Episode:307 Reward:-4.27366670928763
#
# total financial balance: (eur) -48448.94234963985
#
# internal rate of return 0
#
# net present value 0
#
# Episode:308 Reward:-2.2327434993457045
#
# total financial balance: (eur) -48955.329740041656
#
# internal rate of return 0
#
# net present value 0
#
# Episode:309 Reward:-3.4240454737057227
#
# total financial balance: (eur) -54643.499649968
#
# internal rate of return 0
#
# net present value 0
#
# Episode:310 Reward:-1.302223231986587
#
# total financial balance: (eur) -42718.6739318499
#
# internal rate of return 0
#
# net present value 0
#
# Episode:311 Reward:-0.5872130543445724
#
# total financial balance: (eur) -38119.116438984965
#
# internal rate of return 0
#
# net present value 0
#
# Episode:312 Reward:-1.9234718571101315
#
# total financial balance: (eur) -42940.90167869715
#
# internal rate of return 0
#
# net present value 0
#
# Episode:313 Reward:-4.21463177021961
#
# total financial balance: (eur) -55082.49350619329
#
# internal rate of return 0
#
# net present value 0
#
# Episode:314 Reward:-2.880589393941514
#
# total financial balance: (eur) -55175.25333718031
#
# internal rate of return 0
#
# net present value 0
#
# Episode:315 Reward:-2.145231539943398
#
# total financial balance: (eur) -45502.009983518445
#
# internal rate of return 0
#
# net present value 0
#
# Episode:316 Reward:-2.5120823638525245
#
# total financial balance: (eur) -48932.01553026903
#
# internal rate of return 0
#
# net present value 0
#
# Episode:317 Reward:-3.463239096986626
#
# total financial balance: (eur) -50262.74924267456
#
# internal rate of return 0
#
# net present value 0
#
# Episode:318 Reward:-3.2986594084642213
#
# total financial balance: (eur) -40240.59820463664
#
# internal rate of return 0
#
# net present value 0
#
# Episode:319 Reward:-3.3090970082945947
#
# total financial balance: (eur) -62814.836357192755
#
# internal rate of return 0
#
# net present value 0
#
# Episode:320 Reward:-0.17994526589363818
#
# total financial balance: (eur) -47387.511063115446
#
# internal rate of return 0
#
# net present value 0
#
# Episode:321 Reward:-2.5480088058540877
#
# total financial balance: (eur) -33843.53813294059
#
# internal rate of return 0
#
# net present value 0
#
# Episode:322 Reward:-2.0532689579072025
#
# total financial balance: (eur) -50614.83656707153
#
# internal rate of return 0
#
# net present value 0
#
# Episode:323 Reward:-2.5251552887620874
#
# total financial balance: (eur) -52203.034420097836
#
# internal rate of return 0
#
# net present value 0
#
# Episode:324 Reward:-4.194617979361985
#
# total financial balance: (eur) -69241.86414488187
#
# internal rate of return 0
#
# net present value 0
#
# Episode:325 Reward:-0.5600973908989137
#
# total financial balance: (eur) -44811.01711709675
#
# internal rate of return 0
#
# net present value 0
#
# Episode:326 Reward:-3.0944813129670017
#
# total financial balance: (eur) -53084.845518795075
#
# internal rate of return 0
#
# net present value 0
#
# Episode:327 Reward:-0.9109391967988026
#
# total financial balance: (eur) -63384.82064280836
#
# internal rate of return 0
#
# net present value 0
#
# Episode:328 Reward:-2.573307465121211
#
# total financial balance: (eur) -62814.693504444076
#
# internal rate of return 0
#
# net present value 0
#
# Episode:329 Reward:-1.6765068002121248
#
# total financial balance: (eur) -58319.823386449236
#
# internal rate of return 0
#
# net present value 0
#
# Episode:330 Reward:-1.7470472585137882
#
# total financial balance: (eur) -70692.57725187503
#
# internal rate of return 0
#
# net present value 0
#
# Episode:331 Reward:-1.4179281006117042
#
# total financial balance: (eur) -53888.45602205577
#
# internal rate of return 0
#
# net present value 0
#
# Episode:332 Reward:-0.2621690890015934
#
# total financial balance: (eur) -49732.72002632028
#
# internal rate of return 0
#
# net present value 0
#
# Episode:333 Reward:-1.8354855352489554
#
# total financial balance: (eur) -51628.01025446055
#
# internal rate of return 0
#
# net present value 0
#
# Episode:334 Reward:-1.1060845058398194
#
# total financial balance: (eur) -43081.408319573115
#
# internal rate of return 0
#
# net present value 0
#
# Episode:335 Reward:-3.2182550909283796
#
# total financial balance: (eur) -66697.50593940509
#
# internal rate of return 0
#
# net present value 0
#
# Episode:336 Reward:-0.2120077240673727
#
# ...
#
# internal rate of return 0
#
# net present value 0
#
# Episode:890 Reward:-1.0063197709320209
#
# total financial balance: (eur) -53809.039219268554
#
# internal rate of return 0
#
# net present value 0
#
# Episode:891 Reward:-1.0955749521586762
#
# total financial balance: (eur) -52166.62779010438
#
# internal rate of return 0
#
# net present value 0
#
# Episode:892 Reward:-1.811920841519253
#
# total financial balance: (eur) -36521.91933881055
#
# internal rate of return 0
#
# net present value 0
#
# Episode:893 Reward:-2.3616086103504865
#
# total financial balance: (eur) -41745.12424496326
#
# internal rate of return 0
#
# net present value 0
#
# Episode:894 Reward:-2.26740696454702
#
# total financial balance: (eur) -61332.67727103048
#
# internal rate of return 0
#
# net present value 0
#
# Episode:895 Reward:-2.82705444249025
#
# total financial balance: (eur) -41644.45915203427
#
# internal rate of return 0
#
# net present value 0
#
# Episode:896 Reward:-2.4625501560079623
#
# total financial balance: (eur) -31461.889368347434
#
# internal rate of return 0
#
# net present value 0
#
# Episode:897 Reward:-2.7352834879760746
#
# total financial balance: (eur) -42101.28802877218
#
# internal rate of return 0
#
# net present value 0
#
# Episode:898 Reward:-2.0735116382625316
#
# total financial balance: (eur) -38037.17253974171
#
# internal rate of return 0
#
# net present value 0
#
# Episode:899 Reward:-1.5990513886500688
#
# total financial balance: (eur) -55836.949139612865
#
# internal rate of return 0
#
# net present value 0
#
# Episode:900 Reward:-3.3682688517546056
#
# total financial balance: (eur) -53314.585054732954
#
# internal rate of return 0
#
# net present value 0
#
# Episode:901 Reward:-1.4257606663221805
#
# total financial balance: (eur) -43884.97258365233
#
# internal rate of return 0
#
# net present value 0
#
# Episode:902 Reward:-1.6122948564992534
#
# total financial balance: (eur) -63438.36886317733
#
# internal rate of return 0
#
# net present value 0
#
# Episode:903 Reward:-0.7008005560934425
#
# total financial balance: (eur) -52868.91833016636
#
# internal rate of return 0
#
# net present value 0
#
# Episode:904 Reward:-0.5719153332542237
#
# total financial balance: (eur) -35083.10561010014
#
# internal rate of return 0
#
# net present value 0
#
# Episode:905 Reward:0.312943188441364
#
# total financial balance: (eur) -48772.58170046513
#
# internal rate of return 0
#
# net present value 0
#
# Episode:906 Reward:-2.7744229441818926
#
# total financial balance: (eur) -37474.965685195995
#
# internal rate of return 0
#
# net present value 0
#
# Episode:907 Reward:-2.3428117939930586
#
# total financial balance: (eur) -48456.24341135674
#
# internal rate of return 0
#
# net present value 0
#
# Episode:908 Reward:-0.9607245136737433
#
# total financial balance: (eur) -39189.72559869479
#
# internal rate of return 0
#
# net present value 0
#
# Episode:909 Reward:-2.654296309028544
#
# total financial balance: (eur) -40764.151613172886
#
# internal rate of return 0
#
# net present value 0
#
# Episode:910 Reward:-0.6656395255789732
#
# total financial balance: (eur) -44777.78710395896
#
# internal rate of return 0
#
# net present value 0
#
# Episode:911 Reward:-1.4089309145533175
#
# total financial balance: (eur) -57989.85027076197
#
# internal rate of return 0
#
# net present value 0
#
# Episode:912 Reward:-1.5898836338217552
#
# total financial balance: (eur) -31378.883465631843
#
# internal rate of return 0
#
# net present value 0
#
# Episode:913 Reward:-1.7076404159088765
#
# total financial balance: (eur) -55023.01242355256
#
# internal rate of return 0
#
# net present value 0
#
# Episode:914 Reward:-1.463831540215646
#
# total financial balance: (eur) -40301.139060498506
#
# internal rate of return 0
#
# net present value 0
#
# Episode:915 Reward:-1.9481504353642494
#
# total financial balance: (eur) -46167.10704286446
#
# internal rate of return 0
#
# net present value 0
# Episode:916 Reward:-2.1205378338458063
#
# total financial balance: (eur) -63403.967139620676
#
# internal rate of return 0
#
# net present value 0
#
# Episode:917 Reward:-1.661272171717002
#
# total financial balance: (eur) -41379.10117651374
#
# internal rate of return 0
#
# net present value 0
#
# Episode:918 Reward:-1.0189726493730704
#
# total financial balance: (eur) -31420.623135353475
#
# internal rate of return 0
#
# net present value 0
#
# Episode:919 Reward:-3.895228771759377
#
# total financial balance: (eur) -58881.808113827065
#
# internal rate of return 0
#
# net present value 0
#
# Episode:920 Reward:-2.2297168014153916
#
# total financial balance: (eur) -61516.858526437645
#
# internal rate of return 0
#
# net present value 0
#
# Episode:921 Reward:-3.052219836725204
#
# total financial balance: (eur) -51253.24257900636
#
# internal rate of return 0
#
# net present value 0
#
# Episode:922 Reward:-1.7776371873634316
#
# total financial balance: (eur) -60503.90625719632
#
# internal rate of return 0
#
# net present value 0
#
# Episode:923 Reward:-0.9314471308952266
#
# total financial balance: (eur) -45554.748504221854
#
# internal rate of return 0
#
# net present value 0
#
# Episode:924 Reward:-0.8369429306536915
#
# total financial balance: (eur) -59093.393359219735
#
# internal rate of return 0
#
# net present value 0
#
# Episode:925 Reward:-1.9355652734182558
#
# total financial balance: (eur) -38548.66033550628
#
# internal rate of return 0
#
# net present value 0
#
# Episode:926 Reward:-0.5875941490962646
#
# total financial balance: (eur) -31077.692613941326
#
# internal rate of return 0
#
# net present value 0
#
# Episode:927 Reward:-1.8401282537540375
#
# total financial balance: (eur) -47628.55155775773
#
# internal rate of return 0
#
# net present value 0
#
# Episode:928 Reward:-1.4525382227029509
#
# total financial balance: (eur) -45902.15520743354
#
# internal rate of return 0
#
# net present value 0
#
# Episode:929 Reward:-1.8094124718553843
#
# total financial balance: (eur) -71241.86534325538
#
# internal rate of return 0
#
# net present value 0
#
# Episode:930 Reward:-2.9084712997308033
#
# total financial balance: (eur) -54670.237236025925
#
# internal rate of return 0
#
# net present value 0
#
# Episode:931 Reward:-1.818853501313957
#
# total financial balance: (eur) -31152.5846408023
#
# internal rate of return 0
#
# net present value 0
#
# Episode:932 Reward:-2.677753586554918
#
# total financial balance: (eur) -70435.54155820906
#
# internal rate of return 0
#
# net present value 0
#
# Episode:933 Reward:-3.2245428533999005
#
# total financial balance: (eur) -46017.97343049812
#
# internal rate of return 0
#
# net present value 0
#
# Episode:934 Reward:-0.9334063736622802
#
# total financial balance: (eur) -39410.74030417215
#
# internal rate of return 0
#
# net present value 0
#
# Episode:935 Reward:-1.6499701935499627
#
# total financial balance: (eur) -49816.75236271209
#
# internal rate of return 0
#
# net present value 0
#
# Episode:936 Reward:-1.7227698958605477
#
# total financial balance: (eur) -50246.260816938855
#
# internal rate of return 0
#
# net present value 0
#
# Episode:937 Reward:-3.1014653970086354
#
# total financial balance: (eur) -45804.74096457067
#
# internal rate of return 0
#
# net present value 0
#
# Episode:938 Reward:-1.5785828308154888
#
# total financial balance: (eur) -32963.09904841
#
# internal rate of return 0
#
# net present value 0
#
# Episode:939 Reward:-4.15108263689123
#
# total financial balance: (eur) -56607.38450858913
#
# internal rate of return 0
#
# net present value 0
#
# Episode:940 Reward:-1.7609224130272956
#
# total financial balance: (eur) -47638.225551683005
#
# internal rate of return 0
#
# net present value 0
#
# Episode:941 Reward:-2.0002924801410527
#
# total financial balance: (eur) -55456.496269640214
#
# internal rate of return 0
#
# net present value 0
#
# Episode:942 Reward:-3.4235219421753116
#
# total financial balance: (eur) -61706.7930566983
#
# internal rate of return 0
#
# net present value 0
#
# Episode:943 Reward:-2.3051081056571316
#
# total financial balance: (eur) -41032.378264534076
#
# internal rate of return 0
#
# net present value 0
#
# Episode:944 Reward:-3.3978315205930647
#
# total financial balance: (eur) -52306.04505811608
#
# internal rate of return 0
#
# net present value 0
#
# Episode:945 Reward:-0.9006841206697468
#
# total financial balance: (eur) -51670.378706553005
#
# internal rate of return 0
#
# net present value 0
#
# Episode:946 Reward:-3.4754582475453963
#
# total financial balance: (eur) -49189.970912335135
#
# internal rate of return 0
#
# net present value 0
#
# Episode:947 Reward:-1.2203262010926723
#
# total financial balance: (eur) -42893.37060757571
#
# internal rate of return 0
#
# net present value 0
#
# Episode:948 Reward:-3.012808944271799
#
# total financial balance: (eur) -43262.204767154115
#
# internal rate of return 0
#
# net present value 0
#
# Episode:949 Reward:-2.9262274433334743
#
# total financial balance: (eur) -51347.948897459144
#
# internal rate of return 0
#
# net present value 0
#
# Episode:950 Reward:-3.3494549482528653
#
# total financial balance: (eur) -52073.97154356019
#
# internal rate of return 0
#
# net present value 0
#
# Episode:951 Reward:-3.1375768650618414
#
# total financial balance: (eur) -53182.47645452536
#
# internal rate of return 0
#
# net present value 0
#
# Episode:952 Reward:-2.912579374435096
#
# total financial balance: (eur) -47562.35902111503
#
# internal rate of return 0
#
# net present value 0
#
# Episode:953 Reward:-1.5430981192632136
#
# total financial balance: (eur) -38961.4741414391
#
# internal rate of return 0
#
# net present value 0
#
# Episode:954 Reward:-3.7167857383372542
#
# total financial balance: (eur) -67948.28530426018
#
# internal rate of return 0
#
# net present value 0
#
# Episode:955 Reward:-0.7636587963300637
#
# total financial balance: (eur) -50684.81483497886
#
# internal rate of return 0
#
# net present value 0
#
# Episode:956 Reward:-2.3700094845272135
#
# total financial balance: (eur) -60971.398639610445
#
# internal rate of return 0
#
# net present value 0
#
# Episode:957 Reward:-3.527256248855825
#
# total financial balance: (eur) -46127.65976418615
#
# internal rate of return 0
#
# net present value 0
#
# Episode:958 Reward:-1.0883927034124101
#
# total financial balance: (eur) -42651.913269785924
#
# internal rate of return 0
#
# net present value 0
#
# Episode:959 Reward:-1.2113358941198873
#
# total financial balance: (eur) -47208.16856325239
#
# internal rate of return 0
#
# net present value 0
#
# Episode:960 Reward:-4.203230531934303
#
# total financial balance: (eur) -62372.82702227794
#
# internal rate of return 0
#
# net present value 0
#
# Episode:961 Reward:0.44635134443339214
#
# total financial balance: (eur) -45335.135952979435
#
# internal rate of return 0
#
# net present value 0
#
# Episode:962 Reward:-1.6662326109739265
#
# total financial balance: (eur) -54120.52337767967
#
# internal rate of return 0
#
# net present value 0
#
# Episode:963 Reward:-2.931834648092817
#
# total financial balance: (eur) -61032.608950985246
#
# internal rate of return 0
#
# net present value 0
#
# Episode:964 Reward:-3.197321514165902
#
# total financial balance: (eur) -47774.613553697185
#
# internal rate of return 0
#
# net present value 0
#
# Episode:965 Reward:-1.9816971668876604
#
# total financial balance: (eur) -71130.12082692755
#
# internal rate of return 0
#
# net present value 0
#
# Episode:966 Reward:-1.9004531196424512
#
# total financial balance: (eur) -57328.87102124238
#
# internal rate of return 0
#
# net present value 0
#
# Episode:967 Reward:-3.621332817284956
#
# total financial balance: (eur) -56691.53990570985
#
# internal rate of return 0
#
# net present value 0
#
# Episode:968 Reward:-1.7822824181931027
#
# total financial balance: (eur) -46936.45276593871
#
# internal rate of return 0
#
# net present value 0
#
# Episode:969 Reward:-3.1836991974452147
#
# total financial balance: (eur) -49759.36777418558
#
# internal rate of return 0
#
# net present value 0
#
# Episode:970 Reward:0.17515387606369995
#
# total financial balance: (eur) -35937.24748758142
#
# internal rate of return 0
#
# net present value 0
#
# Episode:971 Reward:-2.8722184833392794
#
# total financial balance: (eur) -53669.010038085784
#
# internal rate of return 0
#
# net present value 0
#
# Episode:972 Reward:-1.3408952271662025
#
# total financial balance: (eur) -65143.60759789614
#
# internal rate of return 0
#
# net present value 0
#
# Episode:973 Reward:-1.1104799566479906
#
# total financial balance: (eur) -42869.740065804916
#
# internal rate of return 0
#
# net present value 0
#
# Episode:974 Reward:-2.1887591468852765
#
# total financial balance: (eur) -50181.07284157639
#
# internal rate of return 0
#
# net present value 0
#
# Episode:975 Reward:-2.4013206060519012
#
# total financial balance: (eur) -46479.99384240634
#
# internal rate of return 0
#
# net present value 0
#
# Episode:976 Reward:-1.1143730880576446
#
# total financial balance: (eur) -47117.577326658604
#
# internal rate of return 0
#
# net present value 0
#
# Episode:977 Reward:-1.0376141908823984
#
# total financial balance: (eur) -61195.681722364105
#
# internal rate of return 0
#
# net present value 0
#
# Episode:978 Reward:-1.9118215341016618
#
# total financial balance: (eur) -48281.97136706795
#
# internal rate of return 0
#
# net present value 0
#
# Episode:979 Reward:-0.6471012778206378
#
# total financial balance: (eur) -43484.84172551925
#
# internal rate of return 0
#
# net present value 0
#
# Episode:980 Reward:-1.871417603693519
#
# total financial balance: (eur) -55524.195607625035
#
# internal rate of return 0
#
# net present value 0
#
# Episode:981 Reward:-3.7991146532085414
#
# total financial balance: (eur) -61433.01157544687
#
# internal rate of return 0
#
# net present value 0
#
# Episode:982 Reward:-2.551942014744893
#
# total financial balance: (eur) -56460.55617259717
#
# internal rate of return 0
#
# net present value 0
#
# Episode:983 Reward:-1.750281683555043
#
# total financial balance: (eur) -50220.79839390323
#
# internal rate of return 0
#
# net present value 0
#
# Episode:984 Reward:-3.550234819323018
#
# total financial balance: (eur) -51990.71004193024
#
# internal rate of return 0
#
# net present value 0
#
# Episode:985 Reward:-2.5777693805474176
#
# total financial balance: (eur) -36449.36934959896
#
# internal rate of return 0
#
# net present value 0
#
# Episode:986 Reward:-0.6402140855620587
#
# total financial balance: (eur) -42325.05699702847
#
# internal rate of return 0
#
# net present value 0
# Episode:987 Reward:-0.9718526931593837
#
# total financial balance: (eur) -37669.66387213419
#
# internal rate of return 0
#
# net present value 0
#
# Episode:988 Reward:-4.153487477579377
#
# total financial balance: (eur) -64857.57152623804
#
# internal rate of return 0
#
# net present value 0
#
# Episode:989 Reward:-2.7798356160586537
#
# total financial balance: (eur) -69008.71891319088
#
# internal rate of return 0
#
# net present value 0
#
# Episode:990 Reward:-1.260533106027987
#
# total financial balance: (eur) -62360.55705081051
#
# internal rate of return 0
#
# net present value 0
#
# Episode:991 Reward:-3.293046218260226
#
# total financial balance: (eur) -48526.69514593419
#
# internal rate of return 0
#
# net present value 0
#
# Episode:992 Reward:-2.7906748468486477
#
# total financial balance: (eur) -55719.012808769156
#
# internal rate of return 0
#
# net present value 0
#
# Episode:993 Reward:-0.8838678286865865
#
# total financial balance: (eur) -42560.16820964227
#
# internal rate of return 0
#
# net present value 0
#
# Episode:994 Reward:-3.6392748962758743
#
# total financial balance: (eur) -70542.33899325079
#
# internal rate of return 0
#
# net present value 0
#
# Episode:995 Reward:-2.8226698332656195
#
# total financial balance: (eur) -51260.5762563078
#
# internal rate of return 0
#
# net present value 0
#
# Episode:996 Reward:-2.7576311601106336
#
# total financial balance: (eur) -48807.542817718764
#
# internal rate of return 0
#
# net present value 0
#
# Episode:997 Reward:-1.081306689275303
#
# total financial balance: (eur) -58261.68823862721
#
# internal rate of return 0
#
# net present value 0
#
# Episode:998 Reward:-2.7342291788570643
#
# total financial balance: (eur) -38193.19390883377
#
# internal rate of return 0
#
# net present value 0
#
# Episode:999 Reward:-0.4678835858436937
#
# total financial balance: (eur) -41708.31725159778
#
# internal rate of return 0
#
# net present value 0
#
# Episode:1000 Reward:-2.7027766008351155
#
# total financial balance: (eur) -73435.3268617841
#
# internal rate of return 0
#
# net present value 0
#
# Execution time: 9.367011547088623 seconds

# %%
def make_env(rank: int, seed: int = 0) -> Callable:
    def _init() -> gym.Env:
        random.seed(seed + rank)
        np.random.seed(seed + rank) 
        env = TrainEnvironment(AC_OUTPUT_arr, elec_consum_arr, import_price_rate, import_price_train_arr, Eff_train_arr, CAPEX_JA_train_arr)
        env.reset(seed=seed + rank)
        return env

    return _init
# Number of environments to run in parallel
num_cpu = 16
env = SubprocVecEnv([make_env(i) for i in range(num_cpu)])

# %%
import math
def logarithmic_schedule(initial_value, final_value=0.00001):
    """
    Returns a function that computes a logarithmically decreasing value from initial_value to final_value.
    """
    def func(progress_remaining):
        # Avoid taking log of zero by setting a lower limit close to zero
        epsilon = 0.0001
        progress = max(epsilon, 1 - progress_remaining)
        # Calculate the decay factor using a logarithmic scale
        return final_value + (initial_value - final_value) * math.log(1/progress)
    return func


learning_rate = logarithmic_schedule(0.0001)

# %%
log_path = "./logs/"
eval_callback = EvalCallback(env_test, best_model_save_path = "C:/Users/kubaw/Desktop/DELFT/THESIS/CODE/TEST_MODELS/ja24_low_aa/",
                             log_path = log_path, n_eval_episodes = 750, eval_freq=5000,
                             deterministic=True, render=False)

# %%
policy_kwargs = dict(net_arch=dict(pi=[512, 512], vf=[512, 512]))

# %%
def linear_schedule(initial_value, final_value=0.00001):
    """
    Returns a function that computes a linearly decreasing value from initial_value to final_value.
    """
    def func(progress_remaining):
        # Calculate the decrease based on the remaining progress
        return final_value + (initial_value - final_value) * progress_remaining
    return func

# Define the learning rate using the linear schedule
learning_rate = linear_schedule(0.0003)

# %%
model = PPO("MlpPolicy", env, learning_rate = learning_rate, batch_size = 256, n_epochs = 24, policy_kwargs = policy_kwargs, gamma = 0.99,  verbose=1, tensorboard_log = "C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs")
TIMESTEPS = 8000000
model.learn(total_timesteps = TIMESTEPS, callback=eval_callback)
# Out:
# Using cpu device
# Logging to C:/Users/kubaw/Desktop/DELFT/THESIS\CODE/TEST_MODELS/LOGS/logs\PPO_422
# ------------------------------
# | time/              |       |
# |    fps             | 4939  |
# |    iterations      | 1     |
# |    time_elapsed    | 6     |
# |    total_timesteps | 32768 |
# ------------------------------
# C:\Users\kubaw\miniforge3\envs\pytorch-env\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_3428\2392353474.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
# Eval num_timesteps=47232, episode_reward=28.07 +/- 10.99
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 28.1        |
# | time/                   |             |
# |    total_timesteps      | 47232       |
# | train/                  |             |
# |    approx_kl            | 0.018956501 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | -0.0014     |
# |    learning_rate        | 0.000299    |
# |    loss                 | 26.5        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 81.2        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 1015  |
# |    iterations      | 2     |
# |    time_elapsed    | 64    |
# |    total_timesteps | 65536 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 3           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019049384 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.000298    |
# |    loss                 | 34.5        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 83.4        |
# -----------------------------------------
# Eval num_timesteps=127232, episode_reward=33.36 +/- 12.89
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 33.4        |
# | time/                   |             |
# |    total_timesteps      | 127232      |
# | train/                  |             |
# |    approx_kl            | 0.019104427 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.000296    |
# |    loss                 | 38.9        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 81.4        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 751    |
# |    iterations      | 4      |
# |    time_elapsed    | 174    |
# |    total_timesteps | 131072 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 5           |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.018858328 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.000295    |
# |    loss                 | 39.9        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 82.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 6           |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.019415446 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 29.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 71          |
# -----------------------------------------
# Eval num_timesteps=207232, episode_reward=38.64 +/- 13.74
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.6        |
# | time/                   |             |
# |    total_timesteps      | 207232      |
# | train/                  |             |
# |    approx_kl            | 0.021048881 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.000293    |
# |    loss                 | 33.8        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 65.6        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 718    |
# |    iterations      | 7      |
# |    time_elapsed    | 319    |
# |    total_timesteps | 229376 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 8           |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019978723 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.000292    |
# |    loss                 | 38.8        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 61.7        |
# -----------------------------------------
# Eval num_timesteps=287232, episode_reward=36.98 +/- 12.94
# Episode length: 25.00 +/- 0.00
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 25        |
# |    mean_reward          | 37        |
# | time/                   |           |
# |    total_timesteps      | 287232    |
# | train/                  |           |
# |    approx_kl            | 0.0176042 |
# |    clip_fraction        | 0.284     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.44     |
# |    explained_variance   | 0.363     |
# |    learning_rate        | 0.00029   |
# |    loss                 | 23.7      |
# |    n_updates            | 192       |
# |    policy_gradient_loss | -0.0259   |
# |    value_loss           | 55.4      |
# ---------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 689    |
# |    iterations      | 9      |
# |    time_elapsed    | 427    |
# |    total_timesteps | 294912 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 687         |
# |    iterations           | 10          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.015668442 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.000289    |
# |    loss                 | 26.3        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 11          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.016118238 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.000288    |
# |    loss                 | 24          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# Eval num_timesteps=367232, episode_reward=35.69 +/- 12.91
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 35.7        |
# | time/                   |             |
# |    total_timesteps      | 367232      |
# | train/                  |             |
# |    approx_kl            | 0.016713824 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.000287    |
# |    loss                 | 30.2        |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 645    |
# |    iterations      | 12     |
# |    time_elapsed    | 609    |
# |    total_timesteps | 393216 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 13          |
# |    time_elapsed         | 657         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.015374155 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.000286    |
# |    loss                 | 24.1        |
# |    n_updates            | 288         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 47.5        |
# -----------------------------------------
# Eval num_timesteps=447232, episode_reward=38.32 +/- 13.30
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.3        |
# | time/                   |             |
# |    total_timesteps      | 447232      |
# | train/                  |             |
# |    approx_kl            | 0.014111632 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.000285    |
# |    loss                 | 22.4        |
# |    n_updates            | 312         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 46          |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 629    |
# |    iterations      | 14     |
# |    time_elapsed    | 728    |
# |    total_timesteps | 458752 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 15          |
# |    time_elapsed         | 775         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.011200059 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.000283    |
# |    loss                 | 19.7        |
# |    n_updates            | 336         |
# |    policy_gradient_loss | -0.00915    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 637         |
# |    iterations           | 16          |
# |    time_elapsed         | 822         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.011829674 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.000282    |
# |    loss                 | 18.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00857    |
# |    value_loss           | 44.4        |
# -----------------------------------------
# Eval num_timesteps=527232, episode_reward=36.55 +/- 13.06
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 36.5        |
# | time/                   |             |
# |    total_timesteps      | 527232      |
# | train/                  |             |
# |    approx_kl            | 0.011934823 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.000281    |
# |    loss                 | 25.8        |
# |    n_updates            | 384         |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 44.4        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 628    |
# |    iterations      | 17     |
# |    time_elapsed    | 885    |
# |    total_timesteps | 557056 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 18          |
# |    time_elapsed         | 928         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.010001693 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.00028     |
# |    loss                 | 27.4        |
# |    n_updates            | 408         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 47.9        |
# -----------------------------------------
# Eval num_timesteps=607232, episode_reward=36.93 +/- 13.57
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 36.9        |
# | time/                   |             |
# |    total_timesteps      | 607232      |
# | train/                  |             |
# |    approx_kl            | 0.010371079 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.000279    |
# |    loss                 | 23.2        |
# |    n_updates            | 432         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 47.4        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 626    |
# |    iterations      | 19     |
# |    time_elapsed    | 993    |
# |    total_timesteps | 622592 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 20          |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.009137249 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.000277    |
# |    loss                 | 20.1        |
# |    n_updates            | 456         |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 42.3        |
# -----------------------------------------
# Eval num_timesteps=687232, episode_reward=36.91 +/- 13.28
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 36.9        |
# | time/                   |             |
# |    total_timesteps      | 687232      |
# | train/                  |             |
# |    approx_kl            | 0.008595929 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.000276    |
# |    loss                 | 22.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 42.6        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 620    |
# |    iterations      | 21     |
# |    time_elapsed    | 1109   |
# |    total_timesteps | 688128 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 22          |
# |    time_elapsed         | 1153        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.008940687 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 25.8        |
# |    n_updates            | 504         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 23          |
# |    time_elapsed         | 1201        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.010273358 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.000274    |
# |    loss                 | 18.9        |
# |    n_updates            | 528         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 43.9        |
# -----------------------------------------
# Eval num_timesteps=767232, episode_reward=39.15 +/- 13.76
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 39.1        |
# | time/                   |             |
# |    total_timesteps      | 767232      |
# | train/                  |             |
# |    approx_kl            | 0.009270728 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.000273    |
# |    loss                 | 22.5        |
# |    n_updates            | 552         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 46.2        |
# -----------------------------------------
# New best mean reward!
# -------------------------------
# | time/              |        |
# |    fps             | 617    |
# |    iterations      | 24     |
# |    time_elapsed    | 1274   |
# |    total_timesteps | 786432 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 25          |
# |    time_elapsed         | 1323        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.010260252 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.000271    |
# |    loss                 | 23.4        |
# |    n_updates            | 576         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 43          |
# -----------------------------------------
# Eval num_timesteps=847232, episode_reward=38.28 +/- 13.75
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.3        |
# | time/                   |             |
# |    total_timesteps      | 847232      |
# | train/                  |             |
# |    approx_kl            | 0.009511864 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.00027     |
# |    loss                 | 21.4        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00398    |
# |    value_loss           | 47.4        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 609    |
# |    iterations      | 26     |
# |    time_elapsed    | 1398   |
# |    total_timesteps | 851968 |
# -------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 27           |
# |    time_elapsed         | 1443         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0093309255 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.000269     |
# |    loss                 | 21.1         |
# |    n_updates            | 624          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 44.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 28          |
# |    time_elapsed         | 1488        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.007910922 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.000268    |
# |    loss                 | 26.7        |
# |    n_updates            | 648         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 44.2        |
# -----------------------------------------
# Eval num_timesteps=927232, episode_reward=38.48 +/- 14.20
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.5        |
# | time/                   |             |
# |    total_timesteps      | 927232      |
# | train/                  |             |
# |    approx_kl            | 0.009129325 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.000267    |
# |    loss                 | 21.1        |
# |    n_updates            | 672         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 41.9        |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 608    |
# |    iterations      | 29     |
# |    time_elapsed    | 1561   |
# |    total_timesteps | 950272 |
# -------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 30          |
# |    time_elapsed         | 1608        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.009700989 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.000266    |
# |    loss                 | 22.6        |
# |    n_updates            | 696         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 43.8        |
# -----------------------------------------
# Eval num_timesteps=1007232, episode_reward=38.82 +/- 14.01
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 38.8         |
# | time/                   |              |
# |    total_timesteps      | 1007232      |
# | train/                  |              |
# |    approx_kl            | 0.0088937525 |
# |    clip_fraction        | 0.0854       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.633        |
# |    learning_rate        | 0.000264     |
# |    loss                 | 23.4         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00329     |
# |    value_loss           | 44.5         |
# ------------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 604     |
# |    iterations      | 31      |
# |    time_elapsed    | 1681    |
# |    total_timesteps | 1015808 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 32          |
# |    time_elapsed         | 1727        |
# |    total_timesteps      | 1048576     |
# | train/                  |             |
# |    approx_kl            | 0.008144934 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.000263    |
# |    loss                 | 22.5        |
# |    n_updates            | 744         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 42.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 33          |
# |    time_elapsed         | 1776        |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.008278934 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.000262    |
# |    loss                 | 24.8        |
# |    n_updates            | 768         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# Eval num_timesteps=1087232, episode_reward=39.18 +/- 13.66
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 39.2        |
# | time/                   |             |
# |    total_timesteps      | 1087232     |
# | train/                  |             |
# |    approx_kl            | 0.008235468 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.000261    |
# |    loss                 | 17.6        |
# |    n_updates            | 792         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 42.2        |
# -----------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 604     |
# |    iterations      | 34      |
# |    time_elapsed    | 1844    |
# |    total_timesteps | 1114112 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 35          |
# |    time_elapsed         | 1893        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.009694484 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.00026     |
# |    loss                 | 22          |
# |    n_updates            | 816         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 44          |
# -----------------------------------------
# Eval num_timesteps=1167232, episode_reward=38.38 +/- 13.60
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.4        |
# | time/                   |             |
# |    total_timesteps      | 1167232     |
# | train/                  |             |
# |    approx_kl            | 0.008016029 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.000258    |
# |    loss                 | 21          |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00399    |
# |    value_loss           | 43.1        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 600     |
# |    iterations      | 36      |
# |    time_elapsed    | 1963    |
# |    total_timesteps | 1179648 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 37          |
# |    time_elapsed         | 2009        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.008244311 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.000257    |
# |    loss                 | 19.6        |
# |    n_updates            | 864         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 38          |
# |    time_elapsed         | 2057        |
# |    total_timesteps      | 1245184     |
# | train/                  |             |
# |    approx_kl            | 0.008091705 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.000256    |
# |    loss                 | 21.3        |
# |    n_updates            | 888         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 39.5        |
# -----------------------------------------
# Eval num_timesteps=1247232, episode_reward=39.30 +/- 13.03
# Episode length: 25.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 25           |
# |    mean_reward          | 39.3         |
# | time/                   |              |
# |    total_timesteps      | 1247232      |
# | train/                  |              |
# |    approx_kl            | 0.0074312994 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.968       |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.000255     |
# |    loss                 | 17.2         |
# |    n_updates            | 912          |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 41.7         |
# ------------------------------------------
# New best mean reward!
# --------------------------------
# | time/              |         |
# |    fps             | 601     |
# |    iterations      | 39      |
# |    time_elapsed    | 2123    |
# |    total_timesteps | 1277952 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 40          |
# |    time_elapsed         | 2167        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.008153155 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.000254    |
# |    loss                 | 16.8        |
# |    n_updates            | 936         |
# |    policy_gradient_loss | -0.00354    |
# |    value_loss           | 38.7        |
# -----------------------------------------
# Eval num_timesteps=1327232, episode_reward=38.77 +/- 13.34
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.8        |
# | time/                   |             |
# |    total_timesteps      | 1327232     |
# | train/                  |             |
# |    approx_kl            | 0.007507886 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.000252    |
# |    loss                 | 16.1        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 601     |
# |    iterations      | 41      |
# |    time_elapsed    | 2234    |
# |    total_timesteps | 1343488 |
# --------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 42          |
# |    time_elapsed         | 2279        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.007922545 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.000251    |
# |    loss                 | 20          |
# |    n_updates            | 984         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 36.9        |
# -----------------------------------------
# Eval num_timesteps=1407232, episode_reward=38.14 +/- 13.64
# Episode length: 25.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 25          |
# |    mean_reward          | 38.1        |
# | time/                   |             |
# |    total_timesteps      | 1407232     |
# | train/                  |             |
# |    approx_kl            | 0.008305285 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.7        |
# |    n_updates            | 1008        |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 35.5        |
# -----------------------------------------
# --------------------------------
# | time/              |         |
# |    fps             | 600     |
# |    iterations      | 43      |
# |    time_elapsed    | 2346    |
# |    total_timesteps | 1409024 |
# --------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 602        |
# |    iterations           | 44         |
# |    time_elapsed         | 2391       |
# |    total_timesteps      | 1441792    |
# | train/                  |            |
# |    approx_kl            | 0.00861172 |
# |    clip_fraction        | 0.0737     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.858     |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.000249   |
# |    loss                 | 15.7       |
# |    n_updates            | 1032       |
# |    policy_gradient_loss | -0.00371   |
# |    value_loss           | 34.5       |
# ----------------------------------------
# KeyboardInterrupt

# %%
#model.save(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\FINAL24_ja_low")

# %%
model = PPO.load(r"C:\Users\kubaw\Desktop\DELFT\THESIS\CODE\TEST_MODELS\FINAL24_ja_high.zip")

# %%
evaluate1(1, env_test, model)
# Out:
# Act: 9
#  Obs: [0.8506809  0.8584513  0.9979332  0.9444468  0.94620717 0.8702701
#  0.89418256 0.9858364  0.99208087 0.         0.         0.9894404
#  0.9902745  0.9319078  0.9669751  0.930064   0.9864388  0.9897222
#  0.8567538  0.99934334 0.9690382  0.9883636  0.98566294 0.96554
#  0.07780816 0.08083121 0.04069865 0.6843568  0.22262634 0.06385198
#  0.4304    ]
#  Balance 934.6484733204852
# Act: 1
#  Obs: [0.83448714 0.84543145 0.9839316  0.92941517 0.9384754  0.8553898
#  0.88254833 0.9720743  0.97176784 0.99386346 0.         0.98887855
#  0.9821276  0.918809   0.9589939  0.9213087  0.971079   0.98773867
#  0.8422795  0.9796777  0.9611708  0.97831863 0.9790401  0.9443
#  0.0921257  0.08930569 0.04105865 0.6808497  0.09113253 0.0676831
#  0.9064    ]
#  Balance 1145.615082726474
# Act: 3
#  Obs: [0.98640937 0.8348458  0.97125524 0.91823715 0.92682475 0.8490568
#  0.8809269  0.96460253 0.964308   0.98867255 0.9894532  0.97657263
#  0.974911   0.9099361  0.9591434  0.9067026  0.9565509  0.9706006
#  0.9933011  0.9692458  0.94500977 0.9636699  0.9730638  0.9357928
#  0.09561976 0.0552629  0.04106111 0.5943884  0.14136715 0.07174408
#  0.5552    ]
#  Balance 940.3085509209191
# Act: 2
#  Obs: [0.97475624 0.9986366  0.9594475  0.9080488  0.9212707  0.9913041
#  0.86800444 0.9559388  0.9587844  0.97639394 0.96464133 0.97236705
#  0.9660781  0.897618   0.9488707  0.8924981  0.9341199  0.95408237
#  0.9879687  0.9632052  0.9203248  0.9510968  0.96292406 0.9245241
#  0.10472413 0.07794939 0.04107094 0.5966404  0.09293696 0.07604873
#  0.1336    ]
#  Balance 949.7748806354036
# Act: 1
#  Obs: [0.9634993  0.9809248  0.9484214  0.8948521  0.9177361  0.97815603
#  0.99794745 0.95031995 0.94084823 0.9526498  0.9592584  0.96955997
#  0.9610963  0.89392686 0.929588   0.88909996 0.9157731  0.9394618
#  0.98454905 0.95601743 0.9063338  0.93606067 0.95009947 0.91686004
#  0.10983434 0.04207152 0.04107323 0.57108706 0.06590144 0.
#  0.1368    ]
#  Balance 1529.4394942791862
# Act: 1
#  Obs: [0.9483016  0.9670877  0.9330485  0.898819   0.9055777  0.9678885
#  0.97761977 0.93803096 0.93227535 0.9348593  0.94826454 0.95512635
#  0.9377264  0.8871137  0.9258887  0.9924407  0.89837676 0.92779344
#  0.9728134  0.9451508  0.8918613  0.92522395 0.94390833 0.91225404
#  0.11019813 0.03363205 0.07602565 0.56946665 0.06698449 0.
#  0.9288    ]
#  Balance 1642.1572253391405
# Act: 4
#  Obs: [0.9368994  0.9627754  0.916609   1.0013274  0.89407086 0.95489484
#  0.9633136  0.92683613 0.91717213 0.9250872  0.9251594  0.93997025
#  0.9289183  1.0002288  0.9146217  0.9690141  1.0025158  0.9176952
#  0.95550424 0.93707097 1.0048509  0.9023107  0.9292881  0.9105177
#  0.13504967 0.04121665 0.13812822 0.51394975 0.13299784 0.
#  0.0152    ]
#  Balance 890.3404174180982
# Act: 1
#  Obs: [0.9299922  0.9499109  0.90906024 0.99682856 1.0104346  0.9346675
#  0.9409741  0.9143583  0.9019747  0.9169     0.9120895  0.92545456
#  0.91869867 0.9864659  0.9018668  0.9654691  0.99789274 0.90338385
#  0.9453975  0.9248     0.98188025 0.89667404 0.91543025 0.8972186
#  0.14183883 0.04328867 0.13812873 0.5064812  0.069258   0.
#  0.0344    ]
#  Balance 1743.214934666042
# Act: 1
#  Obs: [0.92655426 0.94064623 0.9034708  0.98114413 1.0012089  0.9322793
#  0.9284936  0.9077178  0.8910838  0.9072404  0.901143   0.91539264
#  0.90711737 0.98401344 0.8957346  0.94560874 0.98844326 0.8954661
#  0.93706214 0.9165231  0.97746134 1.0193481  0.9043004  0.89017534
#  0.1448572  0.04420987 0.16420986 0.49317336 0.07051323 0.
#  0.3664    ]
#  Balance 1773.1536858645768
# Act: 1
#  Obs: [0.91080546 0.9297984  0.90872645 0.96863776 0.9975972  0.9123528
#  0.91501415 0.89558184 0.8758262  0.8926482  0.8901455  0.90447265
#  0.8928792  0.98391926 0.8851567  0.93233496 0.9738504  0.88316554
#  0.92648894 0.9198868  0.96316516 1.0102067  0.8912413  1.0106575
#  0.18209831 0.05557572 0.16420986 0.4847201  0.07177961 0.
#  0.14      ]
#  Balance 1779.3282556174663
# Act: 2
#  Obs: [0.89807427 0.9164717  0.89748055 0.95728123 0.99585795 0.9082951
#  0.90013206 0.88811904 1.0036814  0.8830705  0.8880513  0.89312845
#  0.88829756 0.96852064 0.87255543 0.9228805  0.9694412  1.0108367
#  0.9153479  0.9086763  0.95677793 0.99997276 0.87949765 0.99807036
#  0.18525091 0.05653788 0.16974749 0.50560796 0.0941653  0.
#  0.4184    ]
#  Balance 1910.0353453395373
# Act: 2
#  Obs: [0.88759315 0.9037864  0.8889607  0.95514446 0.9795166  0.90302086
#  0.9062131  0.87677157 0.9899941  0.87285024 0.8692387  0.87159914
#  0.8695483  0.9513401  0.99974644 0.9051399  0.95826167 1.0026973
#  0.9083333  0.89072895 0.94477403 0.9927929  1.0106494  0.99034625
#  0.18813035 0.05741667 0.18077813 0.5319831  0.09611496 0.
#  0.8824    ]
#  Balance 1928.844353431066
# Act: 2
#  Obs: [0.87070125 0.88828903 0.88046306 0.9504382  0.9815592  0.88919514
#  0.90166485 0.86697906 0.98415935 0.85995626 1.0156606  0.8621396
#  1.0077194  0.9381767  0.9783532  0.9079018  0.9367571  1.0012172
#  0.8954606  0.8819654  0.93148977 0.99035794 0.9977789  0.9875441
#  0.19757754 0.06029992 0.18077831 0.45912147 0.09816764 0.
#  0.5504    ]
#  Balance 1939.5120652570542
# Act: 1
#  Obs: [0.85413975 0.8786904  0.87193966 0.94128567 0.97761905 0.8996593
#  0.89375436 0.86664164 0.97681445 1.0075452  1.0014246  0.8529574
#  0.9910866  0.93084013 0.9683888  0.         0.9196819  0.9946947
#  0.88619834 0.8704636  0.92444307 0.9849563  0.98276585 0.9818179
#  0.22994629 0.07017874 0.18282528 0.46074983 0.07716084 0.
#  0.412     ]
#  Balance 2226.928725784337
# Act: 1
#  Obs: [0.84943783 0.86565405 0.85494304 0.9277448  0.9725182  0.8932805
#  0.8803917  0.85214496 0.96076244 0.99489427 0.98490196 0.8448659
#  0.9725446  0.9207617  0.96197873 1.0102568  0.91260237 0.98596644
#  0.8853277  0.8528566  0.91085726 0.97572106 0.97963285 0.97616744
#  0.24595335 0.07506403 0.28252518 0.47136122 0.10230409 0.
#  0.18      ]
#  Balance 2263.9147279586086
# Act: 2
#  Obs: [1.0363737  0.85582274 0.8512335  0.9147751  0.9714938  0.8818263
#  0.8662651  0.830817   0.94536656 0.9768403  0.97530574 1.0425062
#  0.96955717 0.9167655  0.95158786 0.9972227  0.90009344 0.9691526
#  0.8756043  0.84509134 0.9009377  0.97060424 0.967935   0.95568097
#  0.2605994  0.07953396 0.2825252  0.4092348  0.11096194 0.
#  0.1536    ]
#  Balance 2352.4246379543447
# Act: 1
#  Obs: [1.023883   0.85001147 0.84165406 0.90085334 0.957925   0.8753978
#  0.8526361  1.0354875  0.9335544  0.9660458  0.9646987  1.0492685
#  0.9597043  0.90180993 0.94130355 0.9808908  0.8923459  0.9573265
#  0.85747576 0.8250363  0.8862272  0.95620024 0.95951843 0.94000435
#  0.28436795 0.08678803 0.2825252  0.38581574 0.08141283 0.
#  0.2944    ]
#  Balance 2778.618799318506
# Act: 2
#  Obs: [1.0148448  0.8292031  1.0292662  0.8901795  0.948775   0.8620396
#  0.84160656 1.0288062  0.9162861  0.9575202  0.9568193  1.0403404
#  0.95126635 0.8931274  0.92973226 0.96195257 0.8803713  0.96188396
#  0.84876364 1.037806   0.880958   0.9389993  0.95191026 0.92391086
#  0.26504636 0.08089115 0.28879738 0.38479865 0.10593142 0.
#  0.7856    ]
#  Balance 2788.124825333515
# Act: 1
#  Obs: [1.0064206  1.0329106  1.0197661  0.8777867  0.9410778  0.85783625
#  0.84016675 1.0134366  0.90313035 0.95359784 0.9335081  1.0270021
#  0.9357639  0.884642   0.9196825  0.9429521  0.86502486 0.9471668
#  0.842297   1.027471   0.8768915  0.920328   0.9389339  0.90814304
#  0.34865582 0.10640845 0.28879738 0.37200037 0.08440842 0.
#  0.3904    ]
#  Balance 2812.5365274745113
# Act: 2
#  Obs: [0.9968674  1.0233434  1.0128655  0.86211956 0.93580055 0.8475305
#  1.03393    1.0002216  0.8946004  0.9460096  0.9250017  1.0135971
#  0.91945964 0.86524993 0.90635717 0.9328302  0.86082083 0.9342657
#  1.0326473  1.0215645  0.8676754  0.90661556 0.9169333  0.9026323
#  0.30265328 0.09236864 0.28879738 0.34739554 0.10975406 0.
#  0.824     ]
#  Balance 3382.2610960459615
# Act: 5
#  Obs: [0.9874567  1.0126082  0.99612457 1.0339576  0.9315389  1.025369
#  1.0203562  0.9800379  0.8804229  0.9279206  0.92259157 0.99356693
#  0.90825105 1.0305207  0.901045   0.9240369  1.0337586  0.
#  1.0254498  1.0156585  1.0347673  0.9043691  0.9090624  0.8856208
#  0.35876018 0.10949225 0.29254502 0.34646842 0.17886198 0.
#  0.7552    ]
#  Balance 2397.654362692555
# Act: 0
#  Obs: [0.9697684  1.0056604  0.9829626  1.0270052  0.92658293 1.0146888
#  1.0134263  0.96408033 0.86364555 0.91502774 0.9221052  0.9817934
#  0.9014586  1.0303715  0.88623565 0.91806996 1.0220178  0.
#  1.0147697  1.002886   1.0237784  0.8926114  0.89950645 0.8762761
#  0.33154726 0.10118698 0.29254583 0.3441164  0.05973665 0.
#  0.644     ]
#  Balance 3845.268855176275
# Act: 0
#  Obs: [0.9529786  0.99016213 0.97092354 1.0150317  0.91784394 1.0020524
#  1.0084988  0.9573844  0.8592565  0.90433717 0.909034   0.97447914
#  0.892932   1.0183362  0.8870525  0.9072903  1.0143495  0.
#  1.0037078  0.98186934 1.0090767  0.         0.88931024 0.87020063
#  0.39055234 0.1191951  0.29254583 0.36268532 0.06093139 0.
#  0.348     ]
#  Balance 3528.1740564274533
# Act: 0
#  Obs: [0.947183   0.98200756 0.95600486 1.0011257  0.9126527  0.982512
#  1.0002253  0.93950355 0.8573953  0.90791875 0.8908264  0.96260625
#  0.88289005 1.0096498  0.88302445 0.9005956  0.9982752  0.
#  1.0001295  0.9805163  0.99086046 0.         0.8772996  0.85589415
#  0.3983332  0.12156979 0.293019   0.3530706  0.05944784 0.
#  0.6712    ]
#  Balance 3795.363189103803
# Act: 8
#  Obs: [0.94017863 0.9622266  0.94642293 0.9814183  0.8964538  0.9646598
#  0.99477    0.9243765  1.0410933  0.8952083  1.0318507  0.9552847
#  1.0337952  0.9965747  1.0381533  0.8854847  0.9867753  1.0324008
#  0.99734104 0.97816956 0.98739094 1.039977   1.030799   1.03187
#  0.3983332  0.12156979 0.293019   0.3530706  0.27670488 0.01320262
#  0.9296    ]
#  Balance 2461.0126866457003
# total financial balance: (eur) 53738.65525473102 internal rate of return 28.65155125224854

# %%
def evaluate2(episodes, environment, model):
    
    mean_irr = 0
    mean_fin_balance = 0
    irr = 0
    fin_balance = 0
    count = 0
    npv = 0
    list_npv = []

    for ep in range(episodes):

        obs, _ = environment.reset()  # Unpack the tuple and ignore the info part
        done = False

        while not done:
            action, _ = model.predict(obs)  # Now obs is just the observation array
            obs, reward, done, truncated, info = environment.step(action)
            # Extracting the 2nd and 3rd key-value pairs
            keys = list(info.keys())
            values = list(info.values())

            # Getting the 2nd key-value pair
            second_value = values[1]

            # Getting the 3rd key-value pair
    
            third_value = values[2]
            fourth_value = values[4]
        
        fin_balance += second_value
        npv += fourth_value
        count += 1
        
        list_npv.append(fourth_value)
            
    mean_fin_balance = fin_balance/count
    mean_npv = npv/count

    #print(mean_npv)

    environment.close()
    
    return(list_npv)

# %%
values_eval = evaluate2(5000, env_test, model)
# Out:
# C:\Users\kubaw\AppData\Local\Temp\ipykernel_24352\2392353474.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   value = annual_expense / self.current_budget_constraint
